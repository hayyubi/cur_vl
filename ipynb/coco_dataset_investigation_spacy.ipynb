# %% [markdown]
# # Coco Dataset Investigation

# %%
import json
import pickle
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import torch
from pycocotools.coco import COCO
import spacy
# Out:
# /dvmm-filer2/users/hammad/miniconda3/envs/gaila_v2/lib/python3.6/site-packages/torch/cuda/__init__.py:80: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:112.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
from maskrcnn_benchmark.config import cfg
from maskrcnn_benchmark.modeling.language_backbone.transformers import BERT

# %%
nlp = spacy.load("en_core_web_sm")

# %%
ann_file = '../datasets/coco/annotations/captions_train2017.json'
with open(ann_file, 'r') as fin:
    coco_train_anno_all = json.load(fin)

# %%
len(coco_train_anno_all['annotations'])
# Out:
# 591753

# %%
print(coco_train_anno_all['annotations'][0])
# Out:
# {'image_id': 203564, 'id': 37, 'caption': 'A bicycle replica with a clock as the front wheel.'}

# %%
count=1
id=coco_train_anno_all['annotations'][0]['image_id']
for item in coco_train_anno_all['annotations'][1:]:
    if item['image_id'] == id:
        count += 1
print(count)
# Out:
# 5

# %%
tokenizer = BasicTokenizer(do_lower_case=True)

# %%
nltk.pos_tag(tokenizer.tokenize("He takes a banana."))
# Out:
# [('he', 'PRP'), ('takes', 'VBZ'), ('a', 'DT'), ('banana', 'NN'), ('.', '.')]

# %% [markdown]
# # Getting Stats

# %%
# Counts number of examples for each noun 
# for those sentences having number of noun types each of {0,1,2,..max_noun_no,'Rest'}

def per_tp_no_distr_stats(max_noun_no, tp):
    
    noun_distr_per_noun_no = {}
    ex_count_per_noun_no = {}
    img_caps_per_noun_no = {}
    
    for i in range(1,max_noun_no+1):
        noun_distr_per_noun_no[i] = {}
        ex_count_per_noun_no[i] = 0 
        img_caps_per_noun_no[i] = []
        
    noun_distr_per_noun_no['Rest'] = {}
    ex_count_per_noun_no['Rest'] = 0 
    img_caps_per_noun_no['Rest'] = []
    ex_count_per_noun_no[0] = 0 
    img_caps_per_noun_no[0] = []
    
    net_unique_nouns = set()
    
    def put_words_in_dict(d, ws):
        for w in ws:
            if w not in d:
                d[w] = 1
            else:
                d[w] += 1
    
    for item in coco_train_anno_all['annotations']:
        text = item['caption']
        noun_types_per_ex = set()
        
        for tok in nlp(text):
            if tp in tok.tag_:
                noun_types_per_ex.add(str(tok))
                
        no_noun_types_per_ex = len(noun_types_per_ex)
        
        if no_noun_types_per_ex == 0:
            ex_count_per_noun_no[0] += 1
            img_caps_per_noun_no[0].append((item['image_id'], item['id']))
            continue
        
        elif no_noun_types_per_ex <= max_noun_no:
            d_to_fill = noun_distr_per_noun_no[no_noun_types_per_ex]
            ex_count_per_noun_no[no_noun_types_per_ex] += 1
            img_caps_per_noun_no[no_noun_types_per_ex].append((item['image_id'], item['id']))
            
        else:
            d_to_fill = noun_distr_per_noun_no['Rest']
            ex_count_per_noun_no['Rest'] += 1
            img_caps_per_noun_no['Rest'].append((item['image_id'], item['id']))
        
        put_words_in_dict(d_to_fill, noun_types_per_ex)
        net_unique_nouns.update(noun_types_per_ex)
                
    return noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns, img_caps_per_noun_no

# %% [markdown]
# # Plotting Stats

# %%
def plot_bars(values, x_ticklabel, x_label, y_label, title, font_scale=1, rot_angle=0):

    x = np.arange(len(x_ticklabel))  # the label locations
    width = 0.25  # the width of the bars

    with sns.plotting_context("notebook", font_scale=font_scale):
        fig, ax = plt.subplots(figsize=(16.22,10))
        ax.grid(zorder=0)
        rects1 = ax.bar(x - width/2, values, width, label=None, zorder=3)
    
        # Add some text for labels, title and custom x-axis tick labels, etc.
        ax.set_ylabel(y_label)
        ax.set_xlabel(x_label)
        ax.set_title(title)
        ax.set_xticks(x)
        ax.set_xticklabels(x_ticklabel)
        ax.legend()
    
    
        def autolabel(rects):
            """Attach a text label above each bar in *rects*, displaying its height."""
            for rect in rects:
                height = rect.get_height()
                ax.annotate('{}'.format(''),
                            xy=(rect.get_x() + rect.get_width() / 2, height),
                            xytext=(0, 3),  # 3 points vertical offset
                            textcoords="offset points",
                            ha='center', va='bottom')
    
    
        autolabel(rects1)
        for item in ax.get_xticklabels():
            item.set_rotation(rot_angle)
    
        fig.tight_layout()
    
        plt.show()

# %% [markdown]
# ## Getting Noun Stats

# %%
max_noun_no = 3
# noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns, img_caps_per_noun_no = \
#     per_tp_no_distr_stats(max_noun_no, 'NN')

# Loading from saved location
with open('../../data/coco/coco_stats/spacy/3_noun/noun_stats.pkl', 'rb') as f:
    noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns = pickle.load(f)

with open('../../data/coco/coco_stats/spacy/3_noun/img_caps_per_noun_list.pkl', 'rb') as f:
    img_caps_list = pickle.load(f)

# %%
# max_noun_no = 5
# noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns, img_caps_per_noun_no = \
#     per_tp_no_distr_stats(max_noun_no, 'NN')
# 
# # Loading from saved location
# with open('../../data/coco/coco_stats/spacy/5_noun/noun_stats.pkl', 'rb') as f:
#     noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns = pickle.load(f)
# 
# with open('../../data/coco/coco_stats/spacy/5_noun/img_caps_per_noun_list.pkl', 'rb') as f:
#     img_caps_list = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-45-7bac6b35146d> in <module>
#       4
#       5 # Loading from saved location
# ----> 6 with open('../../data/coco/coco_stats/spacy/noun_stats.pkl', 'rb') as f:
#       7     noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns = pickle.load(f)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/coco/coco_stats/spacy/noun_stats.pkl'

# %%
len(img_caps_list)
# Out:
# 4

# %%
img_caps_list[0][:20]
# Out:
# [(16977, 89),
#  (106140, 221),
#  (107990, 3710),
#  (264461, 7049),
#  (306313, 24930),
#  (564911, 27411),
#  (61422, 29247),
#  (443351, 31795),
#  (383601, 32396),
#  (396673, 36245),
#  (122317, 52982),
#  (69773, 57974),
#  (539478, 63173),
#  (265313, 70603),
#  (265313, 72589),
#  (478120, 72833),
#  (265574, 73268),
#  (501385, 73664),
#  (79446, 76515),
#  (482707, 76897)]

# %%
print('Total Examples with {} nouns per example: {}\n\n'.format(0, ex_count_per_noun_no[0]))

for i in range(1,max_noun_no+1):
    print('Total Examples with {} nouns per example: {}'.
          format(i, ex_count_per_noun_no[i]))
    print('Total Unique nouns with {} nouns per example: {}\n'.format(i, len(noun_distr_per_noun_no[i])))
    
print('Total Examples with > {} nouns per example: {}'.format(max_noun_no, ex_count_per_noun_no['Rest']))
print('Total Unique nouns with > {} nouns per example: {}\n'.format(i, len(noun_distr_per_noun_no['Rest'])))

print('Total number of unique nouns: {}'.format(len(net_unique_nouns)))
# Out:
# Total Examples with 0 nouns per example: 14
#
#
# Total Examples with 1 nouns per example: 3158
# Total Unique nouns with 1 nouns per example: 519
#
# Total Examples with 2 nouns per example: 64382
# Total Unique nouns with 2 nouns per example: 4753
#
# Total Examples with 3 nouns per example: 221819
# Total Unique nouns with 3 nouns per example: 11608
#
# Total Examples with > 3 nouns per example: 302380
# Total Unique nouns with > 3 nouns per example: 21803
#
# Total number of unique nouns: 24867

# %% [markdown]
# ## Plotting Noun Stats

# %%
values=[]
for i in range(0,max_noun_no+1):
    values.append(ex_count_per_noun_no[i])
values.append(ex_count_per_noun_no['Rest'])

x_ticklabel = [str(i) + '-set' for i in list(np.arange(max_noun_no+1))] + ['Rest']

plot_bars(values, x_ticklabel, 'Number of nouns per example', 'Number of examples', 
          'Number of examples per noun number')
# Out:
# No handles with labels found to put in legend.

# %%
values=[]
for i in range(1,max_noun_no+1):
    values.append(len(noun_distr_per_noun_no[i])/len(net_unique_nouns))
values.append(len(noun_distr_per_noun_no['Rest'])/len(net_unique_nouns))

x_ticklabel = [str(i) + '-set' for i in list(np.arange(1, max_noun_no+1))] + ['Rest']

plot_bars(values, x_ticklabel, 'Number of nouns per example', 'Unique noun distribution coverage', 
          'Noun Distribution coverage per noun number')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Sets overlap statistics

# %%
coco_caps=COCO(ann_file)
# Out:
# loading annotations into memory...
# Done (t=1.19s)
# creating index...
# index created!

# %%
caps_per_noun_no = {}

for i, img_cap_ids in enumerate(img_caps_list):
    _, cap_ids = zip(*img_cap_ids)
    caps_per_noun_no[i+1] = coco_caps.loadAnns(list(cap_ids))

# %%
prev_overlap_dict = {}

prev_uniq_noun_list=set()
for i in range(2, max_noun_no+2):
    prev_uniq_noun_list.update(set(noun_distr_per_noun_no[i-1]))
    prev_overlap = 0
    new_noun = 0
    for cap_dict in caps_per_noun_no[i]:
        cap = cap_dict['caption']
        tokens = tokenizer.tokenize(cap)
        noun_types_per_ex = set()
        
        found_overlap = 0
        for word, pos in nltk.pos_tag(tokens):
            if 'NN' in pos and word in prev_uniq_noun_list:
                found_overlap += 1
                if found_overlap == i-1:
                    prev_overlap += 1
                    break
                
        if found_overlap < i-1:
            new_noun += 1
        
    prev_overlap_dict[i] = (prev_overlap/len(caps_per_noun_no[i]), new_noun/len(caps_per_noun_no[i]))
    
for noun_no, overlap in prev_overlap_dict.items():
    print(noun_no, overlap)
# Out:
# 2 (0.9752768276874542, 0.024723172312545876)
# 3 (0.9975262888856433, 0.0024737111143566526)
# 4 (0.9990910612270345, 0.0009089387729654701)

# %% [markdown]
# ### Separating Objects by phase of introduction

# %%
with open('../datasets/coco/zero-shot/mscoco_unseen_classes.json', 'r') as fin:
    labels_unseen_2 = json.load(fin)

# %%
with open('../datasets/coco/zero-shot/mscoco_seen_classes.json', 'r') as fin:
    labels_seen_1 = json.load(fin)

# %%
labels_seen_1.remove('background')

# %%
lab_phs_unseen_dict={}
for label in labels_unseen:
    if label in noun_distr_per_noun_no[1]:
        lab_phs_unseen_dict[label] = 1
    elif label in noun_distr_per_noun_no[2]:
        lab_phs_unseen_dict[label] = 2
    elif label in noun_distr_per_noun_no[3]:
        lab_phs_unseen_dict[label] = 3       
    elif label in noun_distr_per_noun_no['Rest']:
        lab_phs_unseen_dict[label] = 4

# %%
lab_phs_unseen_dict
# Out:
# {'umbrella': 1,
#  'cow': 1,
#  'cup': 2,
#  'bus': 1,
#  'keyboard': 1,
#  'skateboard': 1,
#  'dog': 1,
#  'couch': 1,
#  'tie': 1,
#  'snowboard': 2,
#  'sink': 1,
#  'elephant': 1,
#  'cake': 1,
#  'scissors': 1,
#  'airplane': 1,
#  'cat': 1,
#  'knife': 1}

# %%
lab_phs_seen_dict={}
for label in labels_seen:
    if label in noun_distr_per_noun_no[1]:
        lab_phs_seen_dict[label] = 1
    elif label in noun_distr_per_noun_no[2]:
        lab_phs_seen_dict[label] = 2
    elif label in noun_distr_per_noun_no[3]:
        lab_phs_seen_dict[label] = 3       
    elif label in noun_distr_per_noun_no['Rest']:
        lab_phs_seen_dict[label] = 4

# %%
lab_phs_seen_dict
# Out:
# {'toilet': 1,
#  'bicycle': 1,
#  'apple': 1,
#  'train': 1,
#  'laptop': 1,
#  'carrot': 1,
#  'motorcycle': 1,
#  'oven': 1,
#  'chair': 1,
#  'mouse': 2,
#  'boat': 1,
#  'kite': 1,
#  'sheep': 1,
#  'horse': 1,
#  'sandwich': 1,
#  'clock': 1,
#  'tv': 1,
#  'backpack': 1,
#  'toaster': 1,
#  'bowl': 1,
#  'microwave': 1,
#  'bench': 1,
#  'book': 1,
#  'orange': 1,
#  'bird': 1,
#  'pizza': 1,
#  'fork': 2,
#  'frisbee': 1,
#  'bear': 1,
#  'vase': 1,
#  'toothbrush': 1,
#  'spoon': 2,
#  'giraffe': 1,
#  'handbag': 2,
#  'broccoli': 1,
#  'refrigerator': 1,
#  'remote': 1,
#  'surfboard': 1,
#  'car': 1,
#  'bed': 1,
#  'banana': 1,
#  'donut': 1,
#  'skis': 2,
#  'person': 1,
#  'truck': 1,
#  'bottle': 1,
#  'suitcase': 1,
#  'zebra': 1}

# %%
from collections import defaultdict

lab_phs_dict = lab_phs_seen_dict.copy()
lab_phs_dict.update(lab_phs_unseen_dict)
objects_by_phases = defaultdict(list)
for lab, phs in lab_phs_dict.items():
    objects_by_phases[phs].append(lab)
    
objects_by_phases
# Out:
# defaultdict(list,
#             {1: ['toilet',
#               'bicycle',
#               'apple',
#               'train',
#               'laptop',
#               'carrot',
#               'motorcycle',
#               'oven',
#               'chair',
#               'boat',
#               'kite',
#               'sheep',
#               'horse',
#               'sandwich',
#               'clock',
#               'tv',
#               'backpack',
#               'toaster',
#               'bowl',
#               'microwave',
#               'bench',
#               'book',
#               'orange',
#               'bird',
#               'pizza',
#               'frisbee',
#               'bear',
#               'vase',
#               'toothbrush',
#               'giraffe',
#               'broccoli',
#               'refrigerator',
#               'remote',
#               'surfboard',
#               'car',
#               'bed',
#               'banana',
#               'donut',
#               'person',
#               'truck',
#               'bottle',
#               'suitcase',
#               'zebra',
#               'umbrella',
#               'cow',
#               'bus',
#               'keyboard',
#               'skateboard',
#               'dog',
#               'couch',
#               'tie',
#               'sink',
#               'elephant',
#               'cake',
#               'scissors',
#               'airplane',
#               'cat',
#               'knife'],
#              2: ['mouse',
#               'fork',
#               'spoon',
#               'handbag',
#               'skis',
#               'cup',
#               'snowboard']})

# %%
with open('../../data/coco/coco_stats/objects_by_phases.json', 'w') as f:
    json.dump(objects_by_phases, f)

# %%
with open('../datasets/coco/annotations/instances_val2017.json', 'r') as fin:
    coco_val_anno_all = json.load(fin)
labels_all = [item['name'] for item in coco_val_anno_all['categories']]

# %%
lab_phs_all_dict={}
for label in labels_all:
    if label in noun_distr_per_noun_no[1]:
        lab_phs_all_dict[label] = 1
    elif label in noun_distr_per_noun_no[2]:
        lab_phs_all_dict[label] = 2
    elif label in noun_distr_per_noun_no[3]:
        lab_phs_all_dict[label] = 3       
    elif label in noun_distr_per_noun_no['Rest']:
        lab_phs_all_dict[label] = 4

# %%
lab_phs_all_dict
# Out:
# {'person': 1,
#  'bicycle': 1,
#  'car': 1,
#  'motorcycle': 1,
#  'airplane': 1,
#  'bus': 1,
#  'train': 1,
#  'truck': 1,
#  'boat': 1,
#  'bench': 1,
#  'bird': 1,
#  'cat': 1,
#  'dog': 1,
#  'horse': 1,
#  'sheep': 1,
#  'cow': 1,
#  'elephant': 1,
#  'bear': 1,
#  'zebra': 1,
#  'giraffe': 1,
#  'backpack': 1,
#  'umbrella': 1,
#  'handbag': 2,
#  'tie': 1,
#  'suitcase': 1,
#  'frisbee': 1,
#  'skis': 2,
#  'snowboard': 2,
#  'kite': 1,
#  'skateboard': 1,
#  'surfboard': 1,
#  'bottle': 1,
#  'cup': 2,
#  'fork': 2,
#  'knife': 1,
#  'spoon': 2,
#  'bowl': 1,
#  'banana': 1,
#  'apple': 1,
#  'sandwich': 1,
#  'orange': 1,
#  'broccoli': 1,
#  'carrot': 1,
#  'pizza': 1,
#  'donut': 1,
#  'cake': 1,
#  'chair': 1,
#  'couch': 1,
#  'bed': 1,
#  'toilet': 1,
#  'tv': 1,
#  'laptop': 1,
#  'mouse': 2,
#  'remote': 1,
#  'keyboard': 1,
#  'microwave': 1,
#  'oven': 1,
#  'toaster': 1,
#  'sink': 1,
#  'refrigerator': 1,
#  'book': 1,
#  'clock': 1,
#  'vase': 1,
#  'scissors': 1,
#  'toothbrush': 1}

# %%
print(len(labels_all))
print(len(lab_phs_all_dict))
# Out:
# 80
# 65

# %%
two_words_labels = set(labels_all) - set(list(lab_phs_all_dict.keys()))
two_words_labels
# Out:
# {'baseball bat',
#  'baseball glove',
#  'cell phone',
#  'dining table',
#  'fire hydrant',
#  'hair drier',
#  'hot dog',
#  'parking meter',
#  'potted plant',
#  'sports ball',
#  'stop sign',
#  'teddy bear',
#  'tennis racket',
#  'traffic light',
#  'wine glass'}

# %%
def get_phase_of_label(label):
    ph = -1
    if label in noun_distr_per_noun_no[1]:
        ph = 1
    elif label in noun_distr_per_noun_no[2]:
        ph = 2
    elif label in noun_distr_per_noun_no[3]:
        ph = 3
    elif label in noun_distr_per_noun_no['Rest']:
        ph = 4
    return ph

for l in two_words_labels:
    l1, l2 = l.split()
    print(f'{l1}: {get_phase_of_label(l1)} \t {l2}: {get_phase_of_label(l2)}')
# Out:
# dining: 2 	 table: 1
# sports: 1 	 ball: 1
# fire: 1 	 hydrant: 2
# potted: -1 	 plant: 1
# hair: 1 	 drier: 4
# hot: 2 	 dog: 1
# baseball: 1 	 glove: 2
# teddy: 2 	 bear: 1
# parking: 2 	 meter: 2
# cell: 2 	 phone: 1
# wine: 1 	 glass: 1
# traffic: 2 	 light: 2
# baseball: 1 	 bat: 1
# stop: 2 	 sign: 1
# tennis: 2 	 racket: 2

# %% [markdown]
# ### Noun Distribution statistics

# %%
vals = list(noun_distr_per_noun_no[3].values())
keys = list(noun_distr_per_noun_no[3].keys())

sort_idx = list(np.argsort(- np.array(vals)))

x_ticklabel = list(map(keys.__getitem__, sort_idx))[:200]
values = list(map(vals.__getitem__, sort_idx))[:200]

plot_bars(values, x_ticklabel, 'Noun', '# Number', 
          'Number of nouns', rot_angle=90)
# Out:
# No handles with labels found to put in legend.

# %%
values[199]
# Out:
# 659

# %%
values = sorted(list(vals), reverse=True)
print(len(values))
# Out:
# 10003

# %%
# Out:
# {1: {bathroom: 1,
#   stairs: 1,
#   airplane: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   planes: 1,
#   kitchen: 1,
#   kitchen: 1,
#   biplane: 1,
#   cats: 1,
#   cats: 1,
#   bathroom: 1,
#   area: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   tree: 1,
#   bathroom: 1,
#   toilet: 1,
#   bathroom: 1,
#   bathroom: 1,
#   PEOPLE: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   giraffes: 1,
#   bathroom: 1,
#   image: 1,
#   men: 1,
#   people: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   restroom: 1,
#   kitchen: 1,
#   person: 1,
#   airplane: 1,
#   bed: 1,
#   urinals: 1,
#   kitchen: 1,
#   toilet: 1,
#   toilet: 1,
#   kitchen: 1,
#   dogs: 1,
#   bathroom: 1,
#   bathroom: 1,
#   airplane: 1,
#   Bathroom: 1,
#   toothbrush: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   plane: 1,
#   salad: 1,
#   bowl: 1,
#   jet: 1,
#   kitchen: 1,
#   bathroom: 1,
#   toilet: 1,
#   motorcycles: 1,
#   toilet: 1,
#   wall: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   motorcycles: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   bathroom: 1,
#   dessert: 1,
#   pastry: 1,
#   donut: 1,
#   controller: 1,
#   device: 1,
#   dispenser: 1,
#   airplane: 1,
#   man: 1,
#   apples: 1,
#   bedroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   floor: 1,
#   bowl: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   image: 1,
#   image: 1,
#   image: 1,
#   image: 1,
#   bathroom: 1,
#   Motorcycles: 1,
#   kitchen: 1,
#   motorcycle: 1,
#   motorcycle: 1,
#   airplane: 1,
#   scissors: 1,
#   plane: 1,
#   bathroom: 1,
#   airplane: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   plane: 1,
#   airplane: 1,
#   motorcycles: 1,
#   bathroom: 1,
#   giraffes: 1,
#   giraffes: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   bathroom: 1,
#   TOILET: 1,
#   CAT: 1,
#   motorcycles: 1,
#   bathroom: 1,
#   bathroom: 1,
#   woman: 1,
#   dog: 1,
#   sink: 1,
#   planes: 1,
#   bus: 1,
#   hill: 1,
#   outhouse: 1,
#   giraffes: 1,
#   elephant: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bike: 1,
#   jet: 1,
#   person: 1,
#   runway: 1,
#   bathroom: 1,
#   house: 1,
#   motorcycles: 1,
#   bathroom: 1,
#   bathroom: 1,
#   dogs: 1,
#   soup: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   cat: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   street: 1,
#   bathroom: 1,
#   planes: 1,
#   toilet: 1,
#   zone: 1,
#   thing: 1,
#   something: 1,
#   photograph: 1,
#   cat: 1,
#   kitchen: 1,
#   bathroom: 1,
#   shelving: 1,
#   airplane: 1,
#   bathroom: 1,
#   kitchen: 1,
#   trains: 1,
#   kitchen: 1,
#   dog: 1,
#   woman: 1,
#   people: 1,
#   toilet: 1,
#   planes: 1,
#   bird: 1,
#   sky: 1,
#   airplane: 1,
#   people: 1,
#   motorcycles: 1,
#   doors: 1,
#   motorcycle: 1,
#   bathroom: 1,
#   man: 1,
#   plane: 1,
#   pipe: 1,
#   room: 1,
#   kitchen: 1,
#   cats: 1,
#   clock: 1,
#   motorcycles: 1,
#   motorcycle: 1,
#   bikes: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   doors: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   airplane: 1,
#   airplane: 1,
#   bathroom: 1,
#   restroom: 1,
#   plane: 1,
#   road: 1,
#   one: 1,
#   giraffes: 1,
#   giraffes: 1,
#   bus: 1,
#   bus: 1,
#   bus: 1,
#   sign: 1,
#   rock: 1,
#   train: 1,
#   fire: 1,
#   sheep: 1,
#   stoplight: 1,
#   sheep: 1,
#   trains: 1,
#   giraffes: 1,
#   giraffes: 1,
#   skier: 1,
#   giraffes: 1,
#   train: 1,
#   giraffes: 1,
#   tin: 1,
#   duck: 1,
#   horses: 1,
#   plane: 1,
#   giraffes: 1,
#   sign: 1,
#   train: 1,
#   wind: 1,
#   giraffes: 1,
#   stoplights: 1,
#   fire: 1,
#   wires: 1,
#   women: 1,
#   giraffes: 1,
#   birds: 1,
#   pond: 1,
#   giraffes: 1,
#   giraffes: 1,
#   train: 1,
#   giraffes: 1,
#   giraffe: 1,
#   giraffes: 1,
#   giraffe: 1,
#   bus: 1,
#   trains: 1,
#   train: 1,
#   buses: 1,
#   bus: 1,
#   bus: 1,
#   people: 1,
#   plane: 1,
#   sign: 1,
#   bus: 1,
#   sign: 1,
#   giraffes: 1,
#   airplanes: 1,
#   giraffes: 1,
#   cats: 1,
#   bus: 1,
#   train: 1,
#   grass: 1,
#   busses: 1,
#   image: 1,
#   giraffes: 1,
#   hand: 1,
#   airplane: 1,
#   signs: 1,
#   couple: 1,
#   giraffes: 1,
#   image: 1,
#   buses: 1,
#   BIRDS: 1,
#   sun: 1,
#   giraffes: 1,
#   signs: 1,
#   giraffes: 1,
#   giraffes: 1,
#   giraffe: 1,
#   turkey: 1,
#   peacocks: 1,
#   birds: 1,
#   town: 1,
#   image: 1,
#   couple: 1,
#   giraffes: 1,
#   giraffes: 1,
#   zebra: 1,
#   airplane: 1,
#   stoplight: 1,
#   giraffes: 1,
#   signs: 1,
#   giraffe: 1,
#   peacock: 1,
#   giraffes: 1,
#   girioffs: 1,
#   giraffes: 1,
#   plane: 1,
#   plane: 1,
#   image: 1,
#   item: 1,
#   women: 1,
#   man: 1,
#   trains: 1,
#   train: 1,
#   airplane: 1,
#   stoplight: 1,
#   giraffes: 1,
#   bus: 1,
#   fire: 1,
#   giraffes: 1,
#   giraffes: 1,
#   giraffes: 1,
#   bus: 1,
#   giraffe: 1,
#   giraffes: 1,
#   giraffes: 1,
#   boats: 1,
#   sign: 1,
#   giraffes: 1,
#   giraffes: 1,
#   birds: 1,
#   street: 1,
#   backyard: 1,
#   animals: 1,
#   bus: 1,
#   giraffes: 1,
#   cat: 1,
#   cats: 1,
#   train: 1,
#   cats: 1,
#   cats: 1,
#   couple: 1,
#   image: 1,
#   chest: 1,
#   cat: 1,
#   cats: 1,
#   suitcases: 1,
#   cat: 1,
#   forklift: 1,
#   dog: 1,
#   cow: 1,
#   trucks: 1,
#   cat: 1,
#   cows: 1,
#   dog: 1,
#   elephants: 1,
#   kayaks: 1,
#   dog: 1,
#   enclosure: 1,
#   woman: 1,
#   car: 1,
#   trains: 1,
#   image: 1,
#   gentlemen: 1,
#   suitcase: 1,
#   image: 1,
#   tie: 1,
#   trucks: 1,
#   costumes: 1,
#   highway: 1,
#   animals: 1,
#   women: 1,
#   crew: 1,
#   cows: 1,
#   elephants: 1,
#   tie: 1,
#   image: 1,
#   cat: 1,
#   elephants: 1,
#   building: 1,
#   elephants: 1,
#   chair: 1,
#   room: 1,
#   boats: 1,
#   suitcases: 1,
#   boats: 1,
#   suitcase: 1,
#   suitcases: 1,
#   cat: 1,
#   chair: 1,
#   cat: 1,
#   cats: 1,
#   buildings: 1,
#   day: 1,
#   cat: 1,
#   suitcases: 1,
#   cats: 1,
#   boats: 1,
#   elephants: 1,
#   stop: 1,
#   men: 1,
#   men: 1,
#   umbrellas: 1,
#   puppy: 1,
#   train: 1,
#   umbrella: 1,
#   elephants: 1,
#   frisbee: 1,
#   bears: 1,
#   bears: 1,
#   cats: 1,
#   people: 1,
#   bears: 1,
#   ties: 1,
#   people: 1,
#   floor: 1,
#   image: 1,
#   guy: 1,
#   vans: 1,
#   trucks: 1,
#   elephants: 1,
#   bears: 1,
#   bears: 1,
#   kitchen: 1,
#   man: 1,
#   truck: 1,
#   bears: 1,
#   elephants: 1,
#   ANIMALS: 1,
#   cows: 1,
#   elephants: 1,
#   trucks: 1,
#   note: 1,
#   bear: 1,
#   bears: 1,
#   MEN: 1,
#   bears: 1,
#   bears: 1,
#   cows: 1,
#   bears: 1,
#   suitcases: 1,
#   photograph: 1,
#   elephants: 1,
#   man: 1,
#   van: 1,
#   man: 1,
#   boats: 1,
#   bears: 1,
#   family: 1,
#   motorboat: 1,
#   dog: 1,
#   dog: 1,
#   suitcases: 1,
#   cats: 1,
#   cat: 1,
#   cat: 1,
#   elephants: 1,
#   suitcases: 1,
#   cat: 1,
#   dog: 1,
#   image: 1,
#   meaning: 1,
#   elephant: 1,
#   men: 1,
#   boys: 1,
#   people: 1,
#   mother: 1,
#   cows: 1,
#   trucks: 1,
#   dog: 1,
#   panda: 1,
#   bears: 1,
#   bear: 1,
#   suitcases: 1,
#   zebras: 1,
#   horses: 1,
#   dogs: 1,
#   dogs: 1,
#   zebras: 1,
#   cake: 1,
#   bears: 1,
#   bears: 1,
#   art: 1,
#   banana: 1,
#   bears: 1,
#   horse: 1,
#   horses: 1,
#   zebra: 1,
#   bears: 1,
#   frisbee: 1,
#   zebras: 1,
#   animals: 1,
#   broccoli: 1,
#   design: 1,
#   clock: 1,
#   bananas: 1,
#   zebras: 1,
#   zebras: 1,
#   carrots: 1,
#   orange: 1,
#   horses: 1,
#   zebras: 1,
#   men: 1,
#   zebras: 1,
#   man: 1,
#   skateboarders: 1,
#   ramp: 1,
#   dog: 1,
#   horses: 1,
#   toppings: 1,
#   people: 1,
#   child: 1,
#   image: 1,
#   day: 1,
#   zebra: 1,
#   meal: 1,
#   zebras: 1,
#   zebras: 1,
#   image: 1,
#   dogs: 1,
#   plants: 1,
#   people: 1,
#   bears: 1,
#   dogs: 1,
#   orange: 1,
#   dogs: 1,
#   meals: 1,
#   frisbee: 1,
#   zebras: 1,
#   dog: 1,
#   zebra: 1,
#   bears: 1,
#   zebras: 1,
#   meal: 1,
#   bears: 1,
#   object: 1,
#   man: 1,
#   space: 1,
#   dogs: 1,
#   ball: 1,
#   zebras: 1,
#   dish: 1,
#   image: 1,
#   man: 1,
#   panda: 1,
#   orange: 1,
#   bananas: 1,
#   vegetables: 1,
#   skiers: 1,
#   zebra: 1,
#   skier: 1,
#   zebra: 1,
#   something: 1,
#   zebras: 1,
#   image: 1,
#   banana: 1,
#   zebras: 1,
#   zebra: 1,
#   animals: 1,
#   Zebras: 1,
#   ZEBRAS: 1,
#   zebras: 1,
#   dogs: 1,
#   dogs: 1,
#   meal: 1,
#   man: 1,
#   zebras: 1,
#   ZEBRAS: 1,
#   zebras: 1,
#   zebras: 1,
#   sandwiches: 1,
#   horses: 1,
#   food: 1,
#   girl: 1,
#   zebras: 1,
#   zebras: 1,
#   mud: 1,
#   people: 1,
#   zebra: 1,
#   zebras: 1,
#   zebras: 1,
#   image: 1,
#   food: 1,
#   food: 1,
#   food: 1,
#   image: 1,
#   dog: 1,
#   men: 1,
#   zebras: 1,
#   meal: 1,
#   zebras: 1,
#   food: 1,
#   girl: 1,
#   desserts: 1,
#   man: 1,
#   zebras: 1,
#   men: 1,
#   picture: 1,
#   skier: 1,
#   zebra: 1,
#   dogs: 1,
#   people: 1,
#   zebras: 1,
#   zebras: 1,
#   fruits: 1,
#   zebras: 1,
#   fruits: 1,
#   horse: 1,
#   skateboard: 1,
#   zebras: 1,
#   food: 1,
#   vegetables: 1,
#   ski: 1,
#   boy: 1,
#   zebras: 1,
#   zebras: 1,
#   hate: 1,
#   sign: 1,
#   bananas: 1,
#   bears: 1,
#   bears: 1,
#   bananas: 1,
#   zebras: 1,
#   cupcakes: 1,
#   image: 1,
#   dogs: 1,
#   bed: 1,
#   image: 1,
#   pizza: 1,
#   bed: 1,
#   pizza: 1,
#   runner: 1,
#   snowboarder: 1,
#   pizza: 1,
#   cake: 1,
#   boarder: 1,
#   boats: 1,
#   PEOPLE: 1,
#   dogs: 1,
#   pizza: 1,
#   doughnut: 1,
#   cake: 1,
#   workspace: 1,
#   picture: 1,
#   bedroom: 1,
#   bedroom: 1,
#   cat: 1,
#   pizza: 1,
#   surfers: 1,
#   dessert: 1,
#   cat: 1,
#   bedroom: 1,
#   cake: 1,
#   lunch: 1,
#   bedroom: 1,
#   pizza: 1,
#   pizza: 1,
#   dogs: 1,
#   desert: 1,
#   meal: 1,
#   pizza: 1,
#   sandwich: 1,
#   something: 1,
#   shoe: 1,
#   pizza: 1,
#   surfers: 1,
#   woman: 1,
#   wave: 1,
#   pizza: 1,
#   cake: 1,
#   pizzas: 1,
#   products: 1,
#   baby: 1,
#   control: 1,
#   control: 1,
#   surfboarder: 1,
#   pizza: 1,
#   image: 1,
#   bedroom: 1,
#   lunch: 1,
#   pie: 1,
#   cake: 1,
#   pizza: 1,
#   women: 1,
#   image: 1,
#   pizza: 1,
#   woman: 1,
#   pizza: 1,
#   sandwich: 1,
#   dish: 1,
#   cake: 1,
#   equipment: 1,
#   hotdog: 1,
#   woman: 1,
#   pizza: 1,
#   pizza: 1,
#   sustenance: 1,
#   food: 1,
#   computer: 1,
#   mmmm: 1,
#   suit: 1,
#   surfboards: 1,
#   bedroom: 1,
#   boy: 1,
#   person: 1,
#   surfboard: 1,
#   person: 1,
#   controls: 1,
#   racquets: 1,
#   room: 1,
#   dog: 1,
#   pizza: 1,
#   pizza: 1,
#   man: 1,
#   dog: 1,
#   people: 1,
#   Woman: 1,
#   donut: 1,
#   bed: 1,
#   people: 1,
#   toothbrushes: 1,
#   dogs: 1,
#   man: 1,
#   batter: 1,
#   laptops: 1,
#   refrigerators: 1,
#   keyboard: 1,
#   place: 1,
#   bedroom: 1,
#   appetizers: 1,
#   meal: 1,
#   cars: 1,
#   people: 1,
#   room: 1,
#   laptops: 1,
#   batter: 1,
#   field: 1,
#   compartments: 1,
#   house: 1,
#   screen: 1,
#   people: 1,
#   image: 1,
#   books: 1,
#   animal: 1,
#   toy: 1,
#   clock: 1,
#   items: 1,
#   image: 1,
#   animals: 1,
#   couple: 1,
#   computers: 1,
#   phones: 1,
#   vase: 1,
#   girls: 1,
#   fridge: 1,
#   clock: 1,
#   vase: 1,
#   people: 1,
#   image: 1,
#   children: 1,
#   kitchen: 1,
#   kitchen: 1,
#   pizza: 1,
#   bear: 1,
#   freezers: 1,
#   women: 1,
#   guys: 1,
#   clock: 1,
#   animals: 1,
#   basement: 1,
#   image: 1,
#   camera: 1,
#   pizza: 1,
#   bears: 1,
#   people: 1,
#   refrigerator: 1,
#   kind: 1,
#   children: 1,
#   clock: 1,
#   kitchen: 1,
#   kitchen: 1,
#   man: 1,
#   bears: 1,
#   food: 1,
#   image: 1,
#   refrigerator: 1,
#   baby: 1,
#   bed: 1,
#   clock: 1,
#   kitchen: 1,
#   kitchen: 1,
#   place: 1,
#   plants: 1,
#   something: 1,
#   photograph: 1,
#   clocks: 1,
#   image: 1,
#   girl: 1,
#   cookies: 1,
#   people: 1,
#   clock: 1,
#   fridge: 1,
#   pizza: 1,
#   meal: 1,
#   cathedral: 1,
#   fridge: 1,
#   vase: 1,
#   woman: 1,
#   stone: 1,
#   room: 1,
#   vases: 1,
#   dolls: 1,
#   Scissors: 1,
#   flowers: 1,
#   vase: 1,
#   image: 1,
#   objects: 1,
#   people: 1,
#   meal: 1,
#   meal: 1,
#   glass: 1,
#   breakfast: 1,
#   children: 1,
#   vase: 1,
#   glass: 1,
#   roses: 1,
#   bouquet: 1,
#   decorations: 1,
#   vase: 1,
#   item: 1,
#   support: 1,
#   vase: 1,
#   vase: 1,
#   couple: 1,
#   girls: 1,
#   pizza: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   dogs: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   restroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   banana: 1,
#   bathroom: 1,
#   bathroom: 1,
#   man: 1,
#   bathroom: 1,
#   cat: 1,
#   kitchen: 1,
#   bathroom: 1,
#   restroom: 1,
#   scooters: 1,
#   bathroom: 1,
#   kitchen: 1,
#   cat: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   people: 1,
#   KITCHEN: 1,
#   BIKES: 1,
#   sidewalk: 1,
#   bathroom: 1,
#   bathroom: 1,
#   toilet: 1,
#   restroom: 1,
#   dish: 1,
#   bathroom: 1,
#   men: 1,
#   fly: 1,
#   kitchen: 1,
#   bathroom: 1,
#   view: 1,
#   kitchen: 1,
#   kitchen: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   sink: 1,
#   restaurant: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   trick: 1,
#   people: 1,
#   cake: 1,
#   bathroom: 1,
#   apartment: 1,
#   house: 1,
#   girls: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bath: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   image: 1,
#   bath: 1,
#   kitchen: 1,
#   apartment: 1,
#   bathroom: 1,
#   kitchen: 1,
#   glasses: 1,
#   bathroom: 1,
#   kitchen: 1,
#   image: 1,
#   wall: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bathroom: 1,
#   bicycle: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   toilet: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   kitchen: 1,
#   image: 1,
#   bathroom: 1,
#   kitchen: 1,
#   Urinals: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bikes: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   men: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bikes: 1,
#   cat: 1,
#   shade: 1,
#   kitchen: 1,
#   house: 1,
#   kitchen: 1,
#   kitchen: 1,
#   kitchen: 1,
#   area: 1,
#   kitchen: 1,
#   sinks: 1,
#   kitchen: 1,
#   kitchen: 1,
#   bathroom: 1,
#   bathroom: 1,
#   kitchen: 1,
#   bathroom: 1,
#   kitchen: 1,
#   room: 1,
#   kitchen: 1,
#   top: 1,
#   kitchen: 1,
#   bathroom: 1,
#   ...},
#  2: {car: 1,
#   car: 1,
#   airplane: 1,
#   landing: 1,
#   home: 1,
#   kitchen: 1,
#   cucumbers: 1,
#   box: 1,
#   cat: 1,
#   toilet: 1,
#   cow: 1,
#   man: 1,
#   car: 1,
#   street: 1,
#   sky: 1,
#   plane: 1,
#   airplane: 1,
#   sky: 1,
#   bench: 1,
#   purse: 1,
#   box: 1,
#   vegetables: 1,
#   plane: 1,
#   airport: 1,
#   airplane: 1,
#   sky: 1,
#   child: 1,
#   motorcycle: 1,
#   night: 1,
#   intersection: 1,
#   motorcycle: 1,
#   baby: 1,
#   kitchen: 1,
#   refrigerator: 1,
#   boy: 1,
#   motorcycle: 1,
#   airplane: 1,
#   sky: 1,
#   cat: 1,
#   bowl: 1,
#   bathroom: 1,
#   sink: 1,
#   plane: 1,
#   sky: 1,
#   purse: 1,
#   bench: 1,
#   fireplace: 1,
#   fire: 1,
#   plunger: 1,
#   toilet: 1,
#   kitchen: 1,
#   shades: 1,
#   kitten: 1,
#   bowl: 1,
#   jet: 1,
#   tarmac: 1,
#   door: 1,
#   sink: 1,
#   river: 1,
#   bicycle: 1,
#   box: 1,
#   object: 1,
#   curb: 1,
#   car: 1,
#   light: 1,
#   car: 1,
#   television: 1,
#   signs: 1,
#   animals: 1,
#   fence: 1,
#   toilet: 1,
#   toilet: 1,
#   cat: 1,
#   bowl: 1,
#   man: 1,
#   kitchen: 1,
#   beach: 1,
#   sky: 1,
#   plane: 1,
#   sky: 1,
#   sky: 1,
#   airplane: 1,
#   bathrood: 1,
#   objects: 1,
#   woman: 1,
#   umbrella: 1,
#   plane: 1,
#   airport: 1,
#   table: 1,
#   vegetables: 1,
#   bath: 1,
#   room: 1,
#   donuts: 1,
#   hands: 1,
#   meeting: 1,
#   ride: 1,
#   bathroom: 1,
#   sinks: 1,
#   motorcycle: 1,
#   street: 1,
#   image: 1,
#   picture: 1,
#   car: 1,
#   scooter: 1,
#   sheep: 1,
#   pasture: 1,
#   cat: 1,
#   bicycle: 1,
#   car: 1,
#   vespa: 1,
#   strip: 1,
#   man: 1,
#   doorway: 1,
#   bathroom: 1,
#   jar: 1,
#   liquid: 1,
#   car: 1,
#   cow: 1,
#   plane: 1,
#   airstrip: 1,
#   cat: 1,
#   window: 1,
#   clock: 1,
#   stove: 1,
#   girl: 1,
#   motorcycle: 1,
#   People: 1,
#   airplane: 1,
#   toilet: 1,
#   space: 1,
#   woman: 1,
#   umbrella: 1,
#   airplane: 1,
#   airport: 1,
#   cat: 1,
#   bowl: 1,
#   man: 1,
#   street: 1,
#   Passengers: 1,
#   aircraft: 1,
#   motorcycle: 1,
#   asphalt: 1,
#   LEDs: 1,
#   bathroom: 1,
#   people: 1,
#   pizza: 1,
#   sink: 1,
#   wreaths: 1,
#   cat: 1,
#   bowl: 1,
#   sink: 1,
#   mirror: 1,
#   airplanes: 1,
#   sky: 1,
#   plane: 1,
#   sky: 1,
#   man: 1,
#   truck: 1,
#   motorcycle: 1,
#   car: 1,
#   clock: 1,
#   building: 1,
#   jet: 1,
#   landing: 1,
#   toilet: 1,
#   bathroom: 1,
#   bathroom: 1,
#   floor: 1,
#   flooring: 1,
#   bathroom: 1,
#   nascar: 1,
#   man: 1,
#   people: 1,
#   motorcycles: 1,
#   kitchen: 1,
#   nobody: 1,
#   sidewalk: 1,
#   motorcycle: 1,
#   man: 1,
#   kitchen: 1,
#   kitchen: 1,
#   light: 1,
#   person: 1,
#   motorcycle: 1,
#   fixtures: 1,
#   bathroom: 1,
#   sink: 1,
#   bathroom: 1,
#   person: 1,
#   street: 1,
#   toilet: 1,
#   bathroom: 1,
#   people: 1,
#   building: 1,
#   bicycle: 1,
#   cat: 1,
#   cat: 1,
#   bike: 1,
#   oven: 1,
#   light: 1,
#   World: 1,
#   airliner: 1,
#   airplane: 1,
#   jet: 1,
#   bench: 1,
#   people: 1,
#   outhouse: 1,
#   window: 1,
#   airplane: 1,
#   runway: 1,
#   toilet: 1,
#   object: 1,
#   seat: 1,
#   toilet: 1,
#   structuring: 1,
#   porcelain: 1,
#   airplanes: 1,
#   runway: 1,
#   kitchen: 1,
#   floors: 1,
#   urinals: 1,
#   piping: 1,
#   cat: 1,
#   bicycle: 1,
#   wall: 1,
#   bathtub: 1,
#   plane: 1,
#   field: 1,
#   dogs: 1,
#   owners: 1,
#   kitchen: 1,
#   refrigerator: 1,
#   train: 1,
#   neighborhood: 1,
#   people: 1,
#   kitchen: 1,
#   people: 1,
#   photo: 1,
#   airplane: 1,
#   day: 1,
#   cake: 1,
#   people: 1,
#   bathroom: 1,
#   objects: 1,
#   fixtures: 1,
#   bathroom: 1,
#   field: 1,
#   crop: 1,
#   plane: 1,
#   sky: 1,
#   airplane: 1,
#   field: 1,
#   bathroom: 1,
#   bathtub: 1,
#   bathroom: 1,
#   door: 1,
#   highway: 1,
#   airplane: 1,
#   airplane: 1,
#   runway: 1,
#   everything: 1,
#   bathroom: 1,
#   toilet: 1,
#   head: 1,
#   bathroom: 1,
#   color: 1,
#   lamp: 1,
#   building: 1,
#   motorcycles: 1,
#   row: 1,
#   bathroom: 1,
#   wall: 1,
#   airliner: 1,
#   sky: 1,
#   style: 1,
#   bathroom: 1,
#   display: 1,
#   motorcycles: 1,
#   trash: 1,
#   room: 1,
#   jets: 1,
#   tarmac: 1,
#   boat: 1,
#   beach: 1,
#   toilet: 1,
#   planter: 1,
#   airplane: 1,
#   sky: 1,
#   image: 1,
#   bathroom: 1,
#   woman: 1,
#   beach: 1,
#   dirt: 1,
#   toilet: 1,
#   bicycle: 1,
#   man: 1,
#   ship: 1,
#   land: 1,
#   post: 1,
#   vespas: 1,
#   building: 1,
#   equipment: 1,
#   runway: 1,
#   airplane: 1,
#   counter: 1,
#   sinks: 1,
#   person: 1,
#   beds: 1,
#   counter: 1,
#   bathroom: 1,
#   bread: 1,
#   animals: 1,
#   platforms: 1,
#   dishes: 1,
#   home: 1,
#   railing: 1,
#   washroom: 1,
#   toilet: 1,
#   shower: 1,
#   bathroom: 1,
#   beds: 1,
#   bed: 1,
#   cat: 1,
#   toilet: 1,
#   motorcycles: 1,
#   street: 1,
#   day: 1,
#   bus: 1,
#   bathroom: 1,
#   toilet: 1,
#   sink: 1,
#   bathroom: 1,
#   skateboarder: 1,
#   barrier: 1,
#   picture: 1,
#   bathroom: 1,
#   animals: 1,
#   sandwiches: 1,
#   residence: 1,
#   bathroom: 1,
#   speaker: 1,
#   cat: 1,
#   motorcycle: 1,
#   walkway: 1,
#   boat: 1,
#   sand: 1,
#   bathroom: 1,
#   tub: 1,
#   man: 1,
#   motorcycle: 1,
#   airplane: 1,
#   runway: 1,
#   toilet: 1,
#   bathroom: 1,
#   row: 1,
#   Motorcycles: 1,
#   motorcycle: 1,
#   truck: 1,
#   airplane: 1,
#   sky: 1,
#   airplanes: 1,
#   area: 1,
#   motorcycle: 1,
#   street: 1,
#   bathroom: 1,
#   toilet: 1,
#   sky: 1,
#   kite: 1,
#   runway: 1,
#   jet: 1,
#   motorcycle: 1,
#   house: 1,
#   sky: 1,
#   airplane: 1,
#   bathtub: 1,
#   bathroom: 1,
#   umbrella: 1,
#   plunger: 1,
#   plane: 1,
#   runway: 1,
#   bathroom: 1,
#   accents: 1,
#   airplane: 1,
#   passengers: 1,
#   car: 1,
#   motorcycle: 1,
#   road: 1,
#   light: 1,
#   person: 1,
#   toilet: 1,
#   wall: 1,
#   photo: 1,
#   toilet: 1,
#   window: 1,
#   towels: 1,
#   Bathroom: 1,
#   airport: 1,
#   jet: 1,
#   car: 1,
#   cat: 1,
#   towels: 1,
#   bathroom: 1,
#   makeover: 1,
#   bathroom: 1,
#   giraffes: 1,
#   field: 1,
#   person: 1,
#   umbrella: 1,
#   bathroom: 1,
#   street: 1,
#   aircraft: 1,
#   airstrip: 1,
#   motorcycle: 1,
#   car: 1,
#   boat: 1,
#   trailer: 1,
#   sink: 1,
#   toilet: 1,
#   motorcycle: 1,
#   sidewalk: 1,
#   motorcycle: 1,
#   street: 1,
#   floor: 1,
#   bathroom: 1,
#   woman: 1,
#   skillet: 1,
#   wildlife: 1,
#   vegetation: 1,
#   field: 1,
#   airplane: 1,
#   airport: 1,
#   plane: 1,
#   kitchen: 1,
#   office: 1,
#   toilet: 1,
#   area: 1,
#   man: 1,
#   motorcycles: 1,
#   toilet: 1,
#   lawn: 1,
#   cat: 1,
#   floor: 1,
#   box: 1,
#   bench: 1,
#   toilet: 1,
#   countries: 1,
#   pilot: 1,
#   airplane: 1,
#   toilet: 1,
#   sidewalk: 1,
#   aircraft: 1,
#   sky: 1,
#   airplane: 1,
#   area: 1,
#   towels: 1,
#   bathroom: 1,
#   motorcycles: 1,
#   grass: 1,
#   bathtub: 1,
#   cat: 1,
#   furniture: 1,
#   room: 1,
#   dog: 1,
#   cabinet: 1,
#   window: 1,
#   desk: 1,
#   car: 1,
#   trolley: 1,
#   kitchen: 1,
#   cabinets: 1,
#   ANA: 1,
#   airplane: 1,
#   items: 1,
#   desk: 1,
#   bathroom: 1,
#   light: 1,
#   clock: 1,
#   elevator: 1,
#   plane: 1,
#   runway: 1,
#   bathroom: 1,
#   light: 1,
#   train: 1,
#   car: 1,
#   bathroom: 1,
#   wall: 1,
#   bathroom: 1,
#   flooring: 1,
#   stand: 1,
#   bathroom: 1,
#   bathroom: 1,
#   apartment: 1,
#   light: 1,
#   bathroom: 1,
#   seat: 1,
#   shower: 1,
#   airplane: 1,
#   sky: 1,
#   clock: 1,
#   doorway: 1,
#   motorcycle: 1,
#   man: 1,
#   shoes: 1,
#   man: 1,
#   bathroom: 1,
#   mirror: 1,
#   cats: 1,
#   confrontation: 1,
#   plain: 1,
#   airport: 1,
#   urinals: 1,
#   row: 1,
#   urinals: 1,
#   restroom: 1,
#   plane: 1,
#   airport: 1,
#   sign: 1,
#   toilet: 1,
#   doors: 1,
#   dog: 1,
#   bike: 1,
#   wall: 1,
#   bathroom: 1,
#   shower: 1,
#   plane: 1,
#   sky: 1,
#   toilet: 1,
#   request: 1,
#   people: 1,
#   Tv: 1,
#   mirror: 1,
#   sink: 1,
#   row: 1,
#   motorcycles: 1,
#   dog: 1,
#   door: 1,
#   sand: 1,
#   giraffe: 1,
#   words: 1,
#   Man: 1,
#   jet: 1,
#   sky: 1,
#   bikes: 1,
#   place: 1,
#   snow: 1,
#   toilet: 1,
#   kitchen: 1,
#   fridge: 1,
#   air: 1,
#   plane: 1,
#   bathroom: 1,
#   day: 1,
#   plane: 1,
#   sky: 1,
#   animals: 1,
#   tree: 1,
#   giraffes: 1,
#   tree: 1,
#   group: 1,
#   children: 1,
#   picture: 1,
#   woman: 1,
#   motorcycle: 1,
#   checkers: 1,
#   airplane: 1,
#   sky: 1,
#   cats: 1,
#   window: 1,
#   sky: 1,
#   airplane: 1,
#   street: 1,
#   motorcycle: 1,
#   plane: 1,
#   sky: 1,
#   motorcycle: 1,
#   sidewalk: 1,
#   plane: 1,
#   sky: 1,
#   plane: 1,
#   air: 1,
#   bathroom: 1,
#   toilet: 1,
#   tub: 1,
#   bathroom: 1,
#   bathroom: 1,
#   image: 1,
#   motorcycles: 1,
#   man: 1,
#   planes: 1,
#   sky: 1,
#   television: 1,
#   wall: 1,
#   cat: 1,
#   ground: 1,
#   motorcycle: 1,
#   man: 1,
#   top: 1,
#   cat: 1,
#   kitchen: 1,
#   tile: 1,
#   bus: 1,
#   building: 1,
#   people: 1,
#   bench: 1,
#   sheep: 1,
#   field: 1,
#   bathroom: 1,
#   plant: 1,
#   television: 1,
#   dog: 1,
#   plane: 1,
#   tarmac: 1,
#   bananas: 1,
#   bunches: 1,
#   sink: 1,
#   mirror: 1,
#   dog: 1,
#   car: 1,
#   bathroom: 1,
#   doorway: 1,
#   airliner: 1,
#   jet: 1,
#   building: 1,
#   bus: 1,
#   cats: 1,
#   window: 1,
#   motorcycle: 1,
#   man: 1,
#   cat: 1,
#   bathtube: 1,
#   fence: 1,
#   giraffes: 1,
#   tire: 1,
#   motorcycle: 1,
#   runway: 1,
#   airplane: 1,
#   luggage: 1,
#   woman: 1,
#   truck: 1,
#   airplane: 1,
#   clouds: 1,
#   jet: 1,
#   food: 1,
#   plate: 1,
#   toilet: 1,
#   seat: 1,
#   people: 1,
#   jet: 1,
#   STREET: 1,
#   MOTORCYCLE: 1,
#   appliances: 1,
#   kitchen: 1,
#   lambs: 1,
#   pasture: 1,
#   giraffes: 1,
#   habitat: 1,
#   helmet: 1,
#   man: 1,
#   Contrails: 1,
#   jet: 1,
#   kitchen: 1,
#   woman: 1,
#   lighting: 1,
#   mirror: 1,
#   seat: 1,
#   toilet: 1,
#   deck: 1,
#   buses: 1,
#   people: 1,
#   motorcycle: 1,
#   pitcher: 1,
#   urn: 1,
#   girl: 1,
#   cat: 1,
#   bus: 1,
#   intersection: 1,
#   teal: 1,
#   bathroom: 1,
#   dog: 1,
#   car: 1,
#   bathroom: 1,
#   toilet: 1,
#   stalls: 1,
#   toilets: 1,
#   bathroom: 1,
#   door: 1,
#   plane: 1,
#   airport: 1,
#   clock: 1,
#   steeple: 1,
#   man: 1,
#   motorcycles: 1,
#   toilet: 1,
#   sink: 1,
#   couple: 1,
#   men: 1,
#   silver: 1,
#   kitchen: 1,
#   People: 1,
#   pier: 1,
#   girl: 1,
#   cat: 1,
#   airport: 1,
#   Airplanes: 1,
#   bathroom: 1,
#   light: 1,
#   plane: 1,
#   colors: 1,
#   sink: 1,
#   cat: 1,
#   kitchen: 1,
#   floor: 1,
#   bench: 1,
#   park: 1,
#   games: 1,
#   T.V.: 1,
#   walls: 1,
#   bathroom: 1,
#   boat: 1,
#   water: 1,
#   motorcycle: 1,
#   garage: 1,
#   motorcycle: 1,
#   blue: 1,
#   bathroom: 1,
#   window: 1,
#   room: 1,
#   image: 1,
#   plate: 1,
#   Desert: 1,
#   street: 1,
#   street: 1,
#   giraffe: 1,
#   traffic: 1,
#   car: 1,
#   things: 1,
#   person: 1,
#   car: 1,
#   lady: 1,
#   umbrella: 1,
#   toilet: 1,
#   bidet: 1,
#   grass: 1,
#   building: 1,
#   kitchen: 1,
#   people: 1,
#   dog: 1,
#   car: 1,
#   bidet: 1,
#   toilet: 1,
#   tile: 1,
#   bathroom: 1,
#   television: 1,
#   dog: 1,
#   air: 1,
#   plane: 1,
#   car: 1,
#   dog: 1,
#   bidet: 1,
#   toilet: 1,
#   oranges: 1,
#   bowl: 1,
#   dogs: 1,
#   bathroom: 1,
#   tent: 1,
#   field: 1,
#   street: 1,
#   person: 1,
#   reflection: 1,
#   man: 1,
#   sink: 1,
#   bathroom: 1,
#   kitchen: 1,
#   ceiling: 1,
#   picture: 1,
#   kitchen: 1,
#   bathroom: 1,
#   mirror: 1,
#   street: 1,
#   motorcycle: 1,
#   bowls: 1,
#   cats: 1,
#   bathroom: 1,
#   light: 1,
#   motorcycle: 1,
#   cobblestones: 1,
#   woman: 1,
#   motorcycle: 1,
#   bike: 1,
#   bed: 1,
#   way: 1,
#   plane: 1,
#   broncat: 1,
#   car: 1,
#   bathroom: 1,
#   setting: 1,
#   giraffes: 1,
#   photographer: 1,
#   block: 1,
#   knife: 1,
#   toilet: 1,
#   graffiti: 1,
#   bidet: 1,
#   bathroom: 1,
#   bike: 1,
#   building: 1,
#   bus: 1,
#   side: 1,
#   street: 1,
#   night: 1,
#   building: 1,
#   church: 1,
#   area: 1,
#   giraffes: 1,
#   runway: 1,
#   plane: 1,
#   trashcan: 1,
#   kitchen: 1,
#   dog: 1,
#   man: 1,
#   plane: 1,
#   building: 1,
#   apparatus: 1,
#   thicket: 1,
#   plane: 1,
#   way: 1,
#   clock: 1,
#   cabinet: 1,
#   airplane: 1,
#   truck: 1,
#   bench: 1,
#   street: 1,
#   fixtures: 1,
#   bathroom: 1,
#   oranges: 1,
#   bowl: 1,
#   bathroom: 1,
#   photo: 1,
#   lane: 1,
#   motorcycles: 1,
#   church: 1,
#   town: 1,
#   runway: 1,
#   jet: 1,
#   airplane: 1,
#   ground: 1,
#   cat: 1,
#   purse: 1,
#   door: 1,
#   kitchen: 1,
#   people: 1,
#   dog: 1,
#   couch: 1,
#   bicycle: 1,
#   bus: 1,
#   picture: 1,
#   bicycle: 1,
#   basket: 1,
#   kitchen: 1,
#   cabinets: 1,
#   bedroom: 1,
#   bike: 1,
#   person: 1,
#   hill: 1,
#   bathroom: 1,
#   tile: 1,
#   bathroom: 1,
#   toilet: 1,
#   oranges: 1,
#   bowl: 1,
#   person: 1,
#   toilet: 1,
#   family: 1,
#   dog: 1,
#   bathroom: 1,
#   sinks: 1,
#   underside: 1,
#   plane: 1,
#   cat: 1,
#   bathtub: 1,
#   giraffe: 1,
#   vehicles: 1,
#   bathroom: 1,
#   toilet: 1,
#   bathroom: 1,
#   mirror: 1,
#   cat: 1,
#   car: 1,
#   sky: 1,
#   airplane: 1,
#   motorcycle: 1,
#   motorcycle: 1,
#   motorcycles: 1,
#   curb: 1,
#   jet: 1,
#   airport: 1,
#   toilet: 1,
#   bathroom: 1,
#   women: 1,
#   picture: 1,
#   man: 1,
#   bench: 1,
#   tarmac: 1,
#   plane: 1,
#   women: 1,
#   man: 1,
#   air: 1,
#   plane: 1,
#   dogs: 1,
#   leashes: 1,
#   bathroom: 1,
#   sink: 1,
#   bathroom: 1,
#   toilets: 1,
#   laptop: 1,
#   table: 1,
#   woman: 1,
#   water: 1,
#   toilet: 1,
#   bathroom: 1,
#   restroom: 1,
#   toilets: 1,
#   curtains: 1,
#   bathroom: 1,
#   bathroom: 1,
#   cabinet: 1,
#   oranges: 1,
#   bowl: 1,
#   plane: 1,
#   sky: 1,
#   car: 1,
#   road: 1,
#   hill: 1,
#   skier: 1,
#   man: 1,
#   motorcycle: 1,
#   olives: 1,
#   pizza: 1,
#   dog: 1,
#   sheep: 1,
#   stalls: 1,
#   bathroom: 1,
#   plane: 1,
#   airport: 1,
#   clocks: 1,
#   windows: 1,
#   stove: 1,
#   mixer: 1,
#   motorcycle: 1,
#   motorcycles: 1,
#   Chances: 1,
#   travelers: 1,
#   room: 1,
#   storage: 1,
#   men: 1,
#   bench: 1,
#   door: 1,
#   dogs: 1,
#   bathroom: 1,
#   toilet: 1,
#   kitchen: 1,
#   doorway: 1,
#   picture: 1,
#   kitchen: 1,
#   stalls: 1,
#   bathroom: 1,
#   diner: 1,
#   counter: 1,
#   plane: 1,
#   runway: 1,
#   cat: 1,
#   toilet: 1,
#   toilet: 1,
#   bathroom: 1,
#   bikes: 1,
#   building: 1,
#   church: 1,
#   clock: 1,
#   bathroom: 1,
#   process: 1,
#   towels: 1,
#   bathroom: 1,
#   wall: 1,
#   side: 1,
#   airplane: 1,
#   sky: 1,
#   people: 1,
#   cake: 1,
#   kitchen: 1,
#   trimming: 1,
#   gear: 1,
#   metal: 1,
#   sky: 1,
#   lights: 1,
#   water: 1,
#   bathroom: 1,
#   bicycles: 1,
#   picture: 1,
#   cat: 1,
#   door: 1,
#   ...},
#  3: {passenger: 1,
#   air: 1,
#   airplane: 1,
#   sky: 1,
#   GOL: 1,
#   plane: 1,
#   scheme: 1,
#   color: 1,
#   bathroom: 1,
#   bike: 1,
#   tire: 1,
#   clock: 1,
#   sidewalk: 1,
#   cars: 1,
#   street: 1,
#   bathroom: 1,
#   sink: 1,
#   toilet: 1,
#   station: 1,
#   driveway: 1,
#   wagon: 1,
#   road: 1,
#   formation: 1,
#   motorcycles: 1,
#   kitten: 1,
#   dish: 1,
#   table: 1,
#   countertop: 1,
#   bathroom: 1,
#   cabinetry: 1,
#   person: 1,
#   field: 1,
#   crops: 1,
#   husky: 1,
#   windows: 1,
#   car: 1,
#   window: 1,
#   door: 1,
#   kitchen: 1,
#   dog: 1,
#   woman: 1,
#   city: 1,
#   bathroom: 1,
#   shelf: 1,
#   toilet: 1,
#   bathroom: 1,
#   kids: 1,
#   girl: 1,
#   scooter: 1,
#   front: 1,
#   car: 1,
#   area: 1,
#   pinewood: 1,
#   kitchen: 1,
#   man: 1,
#   kitchen: 1,
#   violin: 1,
#   celling: 1,
#   kitchen: 1,
#   cabinets: 1,
#   rain: 1,
#   person: 1,
#   sidewalk: 1,
#   kitchen: 1,
#   furnishings: 1,
#   marble: 1,
#   bathroom: 1,
#   toilet: 1,
#   tile: 1,
#   birds: 1,
#   giraffe: 1,
#   shoulder: 1,
#   sidewalk: 1,
#   dog: 1,
#   woman: 1,
#   man: 1,
#   marina: 1,
#   bike: 1,
#   man: 1,
#   bench: 1,
#   bike: 1,
#   kitchen: 1,
#   window: 1,
#   door: 1,
#   urinals: 1,
#   window: 1,
#   restroom: 1,
#   rain: 1,
#   person: 1,
#   umbrella: 1,
#   skiing: 1,
#   man: 1,
#   photo: 1,
#   wall: 1,
#   urinals: 1,
#   bathroom: 1,
#   picture: 1,
#   kitchen: 1,
#   area: 1,
#   street: 1,
#   motorcycle: 1,
#   one: 1,
#   bicycle: 1,
#   man: 1,
#   bench: 1,
#   crowd: 1,
#   people: 1,
#   bus: 1,
#   person: 1,
#   rain: 1,
#   umbrella: 1,
#   man: 1,
#   airplane: 1,
#   picture: 1,
#   fighter: 1,
#   speed: 1,
#   jet: 1,
#   bunch: 1,
#   bathroom: 1,
#   urinals: 1,
#   airplane: 1,
#   men: 1,
#   runway: 1,
#   cabinets: 1,
#   wood: 1,
#   kitchen: 1,
#   woman: 1,
#   pan: 1,
#   kitchen: 1,
#   motorcycle: 1,
#   boy: 1,
#   car: 1,
#   row: 1,
#   bathroom: 1,
#   urinals: 1,
#   dogs: 1,
#   woman: 1,
#   car: 1,
#   passenger: 1,
#   plane: 1,
#   sky: 1,
#   bathroom: 1,
#   girl: 1,
#   toilet: 1,
#   street: 1,
#   Pedestrians: 1,
#   sidewalk: 1,
#   pan: 1,
#   chef: 1,
#   kitchen: 1,
#   wicker: 1,
#   bathroom: 1,
#   basket: 1,
#   people: 1,
#   ocean: 1,
#   dock: 1,
#   jet: 1,
#   sky: 1,
#   color: 1,
#   row: 1,
#   urinals: 1,
#   window: 1,
#   coconut: 1,
#   plate: 1,
#   cake: 1,
#   bathroom: 1,
#   toilet: 1,
#   trashcan: 1,
#   man: 1,
#   bike: 1,
#   marina: 1,
#   people: 1,
#   beach: 1,
#   front: 1,
#   house: 1,
#   kitchen: 1,
#   photograph: 1,
#   forest: 1,
#   man: 1,
#   country: 1,
#   propeller: 1,
#   tarmac: 1,
#   airplane: 1,
#   back: 1,
#   birds: 1,
#   giraffe: 1,
#   fur: 1,
#   birds: 1,
#   giraffe: 1,
#   day: 1,
#   beach: 1,
#   couple: 1,
#   man: 1,
#   cow: 1,
#   ground: 1,
#   sign: 1,
#   restaurant: 1,
#   building: 1,
#   break: 1,
#   man: 1,
#   bicycle: 1,
#   bathroom: 1,
#   sink: 1,
#   toilet: 1,
#   row: 1,
#   urinals: 1,
#   window: 1,
#   tile: 1,
#   toilet: 1,
#   floor: 1,
#   runway: 1,
#   plane: 1,
#   airport: 1,
#   water: 1,
#   boat: 1,
#   car: 1,
#   car: 1,
#   lake: 1,
#   water: 1,
#   sign: 1,
#   Scotland: 1,
#   bike: 1,
#   bike: 1,
#   front: 1,
#   sign: 1,
#   counters: 1,
#   kitchen: 1,
#   lights: 1,
#   chocolate: 1,
#   box: 1,
#   bananas: 1,
#   car: 1,
#   street: 1,
#   side: 1,
#   cat: 1,
#   toilet: 1,
#   head: 1,
#   toilet: 1,
#   plunger: 1,
#   rug: 1,
#   jet: 1,
#   airport: 1,
#   runway: 1,
#   car: 1,
#   boat: 1,
#   water: 1,
#   sign: 1,
#   building: 1,
#   restaurant: 1,
#   couple: 1,
#   sky: 1,
#   birds: 1,
#   man: 1,
#   kitchen: 1,
#   fiddle: 1,
#   lemons: 1,
#   preparation: 1,
#   salmon: 1,
#   cat: 1,
#   toilet: 1,
#   water: 1,
#   trash: 1,
#   bathroom: 1,
#   toilet: 1,
#   walls: 1,
#   room: 1,
#   cabinets: 1,
#   dishes: 1,
#   sink: 1,
#   kitchen: 1,
#   man: 1,
#   pan: 1,
#   food: 1,
#   bathroom: 1,
#   side: 1,
#   door: 1,
#   welcome: 1,
#   Scotland: 1,
#   bicycle: 1,
#   Guy: 1,
#   cow: 1,
#   floor: 1,
#   fireplace: 1,
#   room: 1,
#   baskets: 1,
#   kitchen: 1,
#   dishes: 1,
#   stove: 1,
#   woman: 1,
#   pan: 1,
#   kitchen: 1,
#   restaurant: 1,
#   sign: 1,
#   food: 1,
#   field: 1,
#   horses: 1,
#   building: 1,
#   plane: 1,
#   area: 1,
#   landing: 1,
#   toilet: 1,
#   sink: 1,
#   bathroom: 1,
#   bathroom: 1,
#   toilet: 1,
#   shelves: 1,
#   room: 1,
#   fireplace: 1,
#   clutter: 1,
#   car: 1,
#   display: 1,
#   street: 1,
#   jet: 1,
#   airport: 1,
#   passenger: 1,
#   cake: 1,
#   Half: 1,
#   plate: 1,
#   woods: 1,
#   people: 1,
#   skis: 1,
#   photograph: 1,
#   renovations: 1,
#   bathroom: 1,
#   window: 1,
#   bathroom: 1,
#   light: 1,
#   girl: 1,
#   bathroom: 1,
#   dress: 1,
#   jet: 1,
#   fighter: 1,
#   sky: 1,
#   airport: 1,
#   tarmac: 1,
#   men: 1,
#   man: 1,
#   bench: 1,
#   bicycle: 1,
#   train: 1,
#   group: 1,
#   people: 1,
#   set: 1,
#   motorcycles: 1,
#   street: 1,
#   altitude: 1,
#   fighter: 1,
#   jet: 1,
#   man: 1,
#   bike: 1,
#   dirt: 1,
#   children: 1,
#   area: 1,
#   children: 1,
#   kitchen: 1,
#   area: 1,
#   lights: 1,
#   girl: 1,
#   restroom: 1,
#   dress: 1,
#   pot: 1,
#   food: 1,
#   man: 1,
#   intersection: 1,
#   mopeds: 1,
#   motorcycles: 1,
#   man: 1,
#   bike: 1,
#   area: 1,
#   car: 1,
#   sun: 1,
#   intersection: 1,
#   scenery: 1,
#   umbrella: 1,
#   People: 1,
#   bicycle: 1,
#   area: 1,
#   rail: 1,
#   car: 1,
#   cow: 1,
#   lot: 1,
#   airport: 1,
#   men: 1,
#   tarmac: 1,
#   bathroom: 1,
#   toilette: 1,
#   shower: 1,
#   girl: 1,
#   bathroom: 1,
#   dress: 1,
#   Women: 1,
#   bakery: 1,
#   kitchen: 1,
#   bench: 1,
#   purse: 1,
#   park: 1,
#   riders: 1,
#   motorcycles: 1,
#   street: 1,
#   street: 1,
#   group: 1,
#   motorcycles: 1,
#   motorcycle: 1,
#   sidewalk: 1,
#   buildings: 1,
#   items: 1,
#   kitchen: 1,
#   man: 1,
#   woman: 1,
#   pan: 1,
#   kitchen: 1,
#   jar: 1,
#   objects: 1,
#   liquid: 1,
#   smoke: 1,
#   tricks: 1,
#   airplane: 1,
#   bikers: 1,
#   lot: 1,
#   parking: 1,
#   person: 1,
#   umbrella: 1,
#   fountain: 1,
#   car: 1,
#   light: 1,
#   rain: 1,
#   sink: 1,
#   stool: 1,
#   mirrors: 1,
#   restroom: 1,
#   urinals: 1,
#   mens: 1,
#   bathroom: 1,
#   bookshelf: 1,
#   toilet: 1,
#   motorcyclist: 1,
#   air: 1,
#   handlebars: 1,
#   landscape: 1,
#   airplane: 1,
#   view: 1,
#   toilet: 1,
#   bathroom: 1,
#   sink: 1,
#   ascent: 1,
#   airplane: 1,
#   skies: 1,
#   toilet: 1,
#   toilets: 1,
#   stall: 1,
#   airplane: 1,
#   others: 1,
#   airport: 1,
#   truck: 1,
#   man: 1,
#   window: 1,
#   platform: 1,
#   bathroom: 1,
#   Tub: 1,
#   toilette: 1,
#   toilette: 1,
#   bathroom: 1,
#   umbrella: 1,
#   rain: 1,
#   lady: 1,
#   ATV: 1,
#   man: 1,
#   cows: 1,
#   bathroom: 1,
#   mirrors: 1,
#   sinks: 1,
#   man: 1,
#   monument: 1,
#   umbrella: 1,
#   guy: 1,
#   woman: 1,
#   motorcycle: 1,
#   restaurant: 1,
#   conversation: 1,
#   men: 1,
#   home: 1,
#   violin: 1,
#   man: 1,
#   man: 1,
#   cows: 1,
#   tractor: 1,
#   kitchen: 1,
#   house: 1,
#   door: 1,
#   airplane: 1,
#   runway: 1,
#   men: 1,
#   rod: 1,
#   sculpture: 1,
#   sidewalk: 1,
#   woman: 1,
#   teddy: 1,
#   bear: 1,
#   valley: 1,
#   sheep: 1,
#   pasture: 1,
#   bathroom: 1,
#   sink: 1,
#   mirrors: 1,
#   umbrella: 1,
#   man: 1,
#   area: 1,
#   back: 1,
#   elephants: 1,
#   people: 1,
#   sink: 1,
#   bathroom: 1,
#   shower: 1,
#   cat: 1,
#   sink: 1,
#   bathroom: 1,
#   Frisbee: 1,
#   man: 1,
#   air: 1,
#   area: 1,
#   work: 1,
#   room: 1,
#   front: 1,
#   motorcycle: 1,
#   trees: 1,
#   man: 1,
#   street: 1,
#   bike: 1,
#   road: 1,
#   side: 1,
#   motorcycle: 1,
#   motorcycle: 1,
#   cobblestone: 1,
#   road: 1,
#   seat: 1,
#   toilet: 1,
#   bathroom: 1,
#   pad: 1,
#   cat: 1,
#   top: 1,
#   city: 1,
#   neighborhood: 1,
#   Pedestrians: 1,
#   parking: 1,
#   signs: 1,
#   garage: 1,
#   tree: 1,
#   frisbee: 1,
#   someone: 1,
#   skateboarder: 1,
#   skateboard: 1,
#   night: 1,
#   jar: 1,
#   table: 1,
#   sangria: 1,
#   plane: 1,
#   landscape: 1,
#   view: 1,
#   pasture: 1,
#   flock: 1,
#   sheep: 1,
#   adult: 1,
#   kitchen: 1,
#   child: 1,
#   sky: 1,
#   jet: 1,
#   condensation: 1,
#   motorcycle: 1,
#   man: 1,
#   woman: 1,
#   motorcyclists: 1,
#   pavement: 1,
#   bikes: 1,
#   woman: 1,
#   man: 1,
#   kitchen: 1,
#   motorcycle: 1,
#   shrubs: 1,
#   front: 1,
#   man: 1,
#   road: 1,
#   herds: 1,
#   team: 1,
#   chefs: 1,
#   meal: 1,
#   exterior: 1,
#   planes: 1,
#   airport: 1,
#   cow: 1,
#   car: 1,
#   mud: 1,
#   outside: 1,
#   cat: 1,
#   door: 1,
#   person: 1,
#   oven: 1,
#   kitchen: 1,
#   wall: 1,
#   man: 1,
#   kitchen: 1,
#   man: 1,
#   window: 1,
#   truck: 1,
#   motorcycle: 1,
#   man: 1,
#   woman: 1,
#   man: 1,
#   kitchen: 1,
#   violin: 1,
#   toilet: 1,
#   bowl: 1,
#   functions: 1,
#   bike: 1,
#   cat: 1,
#   tire: 1,
#   photo: 1,
#   airplane: 1,
#   landscape: 1,
#   shop: 1,
#   people: 1,
#   bike: 1,
#   picture: 1,
#   runway: 1,
#   plane: 1,
#   doorway: 1,
#   wall: 1,
#   room: 1,
#   field: 1,
#   cow: 1,
#   car: 1,
#   bathroom: 1,
#   sink: 1,
#   toilet: 1,
#   cat: 1,
#   cat: 1,
#   window: 1,
#   bicycle: 1,
#   boy: 1,
#   street: 1,
#   photos: 1,
#   kitchen: 1,
#   women: 1,
#   bathroom: 1,
#   cat: 1,
#   sink: 1,
#   pasture: 1,
#   herd: 1,
#   sheep: 1,
#   kitchen: 1,
#   cabinet: 1,
#   man: 1,
#   object: 1,
#   male: 1,
#   tree: 1,
#   park: 1,
#   trees: 1,
#   benches: 1,
#   air: 1,
#   frisbee: 1,
#   man: 1,
#   driveway: 1,
#   display: 1,
#   motorcycle: 1,
#   country: 1,
#   train: 1,
#   area: 1,
#   woman: 1,
#   umbrella: 1,
#   sidewalk: 1,
#   couple: 1,
#   resort: 1,
#   people: 1,
#   window: 1,
#   front: 1,
#   cat: 1,
#   mirrors: 1,
#   bathroom: 1,
#   sinks: 1,
#   road: 1,
#   motorcycle: 1,
#   motorcycle: 1,
#   set: 1,
#   steps: 1,
#   skateboarder: 1,
#   toilet: 1,
#   control: 1,
#   kind: 1,
#   street: 1,
#   Vehicles: 1,
#   directions: 1,
#   control: 1,
#   toilet: 1,
#   buttons: 1,
#   city: 1,
#   night: 1,
#   streets: 1,
#   wreaths: 1,
#   twig: 1,
#   bathroom: 1,
#   cat: 1,
#   barn: 1,
#   field: 1,
#   oven: 1,
#   kitchen: 1,
#   woman: 1,
#   fruit: 1,
#   baskets: 1,
#   vegetables: 1,
#   street: 1,
#   person: 1,
#   city: 1,
#   phone: 1,
#   man: 1,
#   pedestal: 1,
#   kitchen: 1,
#   pots: 1,
#   grill: 1,
#   sky: 1,
#   airplane: 1,
#   part: 1,
#   wheel: 1,
#   cat: 1,
#   bicycle: 1,
#   kitten: 1,
#   woman: 1,
#   purse: 1,
#   group: 1,
#   sheep: 1,
#   field: 1,
#   motorcycle: 1,
#   driveway: 1,
#   day: 1,
#   plane: 1,
#   mountainside: 1,
#   view: 1,
#   Cars: 1,
#   street: 1,
#   pedestrians: 1,
#   cow: 1,
#   car: 1,
#   field: 1,
#   grass: 1,
#   rider: 1,
#   motorcycle: 1,
#   cat: 1,
#   barn: 1,
#   door: 1,
#   sheep: 1,
#   woman: 1,
#   legs: 1,
#   propeller: 1,
#   plane: 1,
#   Passengers: 1,
#   giraffes: 1,
#   eating: 1,
#   trees: 1,
#   church: 1,
#   sun: 1,
#   pews: 1,
#   sheep: 1,
#   man: 1,
#   farm: 1,
#   airport: 1,
#   airplane: 1,
#   runway: 1,
#   opening: 1,
#   cat: 1,
#   doors: 1,
#   woman: 1,
#   lime: 1,
#   kitchen: 1,
#   motorcycle: 1,
#   side: 1,
#   car: 1,
#   airplane: 1,
#   ground: 1,
#   view: 1,
#   car: 1,
#   water: 1,
#   boat: 1,
#   street: 1,
#   skateboard: 1,
#   man: 1,
#   workers: 1,
#   customers: 1,
#   restaurant: 1,
#   steel: 1,
#   lighting: 1,
#   kitchen: 1,
#   cat: 1,
#   purse: 1,
#   image: 1,
#   snow: 1,
#   street: 1,
#   person: 1,
#   airport: 1,
#   tarmac: 1,
#   airplane: 1,
#   people: 1,
#   bus: 1,
#   lane: 1,
#   fabric: 1,
#   piece: 1,
#   cat: 1,
#   motorcycle: 1,
#   cart: 1,
#   dog: 1,
#   area: 1,
#   sign: 1,
#   fall: 1,
#   kitchen: 1,
#   pots: 1,
#   stove: 1,
#   shirt: 1,
#   jeans: 1,
#   skateboarder: 1,
#   stairs: 1,
#   girl: 1,
#   dog: 1,
#   church: 1,
#   Sun: 1,
#   pew: 1,
#   Women: 1,
#   picture: 1,
#   teeth: 1,
#   turn: 1,
#   onlookers: 1,
#   Motorcyclist: 1,
#   dishes: 1,
#   kitchen: 1,
#   appliances: 1,
#   man: 1,
#   yard: 1,
#   frisbee: 1,
#   kite: 1,
#   man: 1,
#   park: 1,
#   officer: 1,
#   Police: 1,
#   motorcycle: 1,
#   park: 1,
#   kite: 1,
#   man: 1,
#   skiing: 1,
#   tent: 1,
#   lodge: 1,
#   vanity: 1,
#   mirror: 1,
#   bathroom: 1,
#   boarder: 1,
#   night: 1,
#   skate: 1,
#   bathroom: 1,
#   sink: 1,
#   mirror: 1,
#   airplanes: 1,
#   display: 1,
#   fence: 1,
#   airport: 1,
#   tarmac: 1,
#   airplane: 1,
#   front: 1,
#   boy: 1,
#   car: 1,
#   group: 1,
#   wild: 1,
#   animals: 1,
#   ocean: 1,
#   motorcycle: 1,
#   person: 1,
#   style: 1,
#   people: 1,
#   bathroom: 1,
#   wall: 1,
#   sheep: 1,
#   cement: 1,
#   candles: 1,
#   cake: 1,
#   People: 1,
#   shower: 1,
#   bathroom: 1,
#   curtain: 1,
#   bathtub: 1,
#   bathroom: 1,
#   mirror: 1,
#   teeth: 1,
#   woman: 1,
#   friend: 1,
#   bench: 1,
#   bush: 1,
#   metal: 1,
#   child: 1,
#   appliance: 1,
#   front: 1,
#   motorcycle: 1,
#   People: 1,
#   roadway: 1,
#   motorcycle: 1,
#   tree: 1,
#   thing: 1,
#   brickwork: 1,
#   detail: 1,
#   cathedral: 1,
#   elephant: 1,
#   jeep: 1,
#   road: 1,
#   teeth: 1,
#   bathroom: 1,
#   women: 1,
#   brick: 1,
#   motorcycle: 1,
#   street: 1,
#   cat: 1,
#   purse: 1,
#   saying: 1,
#   airport: 1,
#   liner: 1,
#   runway: 1,
#   pots: 1,
#   kitchen: 1,
#   pans: 1,
#   man: 1,
#   building: 1,
#   bicycles: 1,
#   terrain: 1,
#   plane: 1,
#   Mountains: 1,
#   crowd: 1,
#   policeman: 1,
#   motorcycle: 1,
#   towels: 1,
#   bathroom: 1,
#   door: 1,
#   motorcycle: 1,
#   car: 1,
#   side: 1,
#   field: 1,
#   animals: 1,
#   group: 1,
#   woman: 1,
#   top: 1,
#   sheep: 1,
#   boat: 1,
#   bikes: 1,
#   board: 1,
#   car: 1,
#   dogs: 1,
#   window: 1,
#   bathroom: 1,
#   walls: 1,
#   toilet: 1,
#   dog: 1,
#   people: 1,
#   snow: 1,
#   people: 1,
#   snow: 1,
#   dog: 1,
#   oven: 1,
#   light: 1,
#   kitchen: 1,
#   cat: 1,
#   toilet: 1,
#   lid: 1,
#   wood: 1,
#   home: 1,
#   lots: 1,
#   shore: 1,
#   person: 1,
#   motorcycle: 1,
#   plane: 1,
#   chemtrails: 1,
#   jet: 1,
#   horses: 1,
#   people: 1,
#   road: 1,
#   cat: 1,
#   sink: 1,
#   bathroom: 1,
#   giraffes: 1,
#   trees: 1,
#   front: 1,
#   living: 1,
#   room: 1,
#   television: 1,
#   bathroom: 1,
#   toilet: 1,
#   sink: 1,
#   clock: 1,
#   building: 1,
#   tower: 1,
#   basket: 1,
#   dog: 1,
#   owner: 1,
#   burners: 1,
#   decorations: 1,
#   timer: 1,
#   motorcycle: 1,
#   person: 1,
#   animal: 1,
#   wall: 1,
#   ...},
#  4: {bicycle: 1,
#   wheel: 1,
#   clock: 1,
#   replica: 1,
#   door: 1,
#   walls: 1,
#   room: 1,
#   sink: 1,
#   baby: 1,
#   bathroom: 1,
#   walls: 1,
#   blue: 1,
#   bathroom: 1,
#   sink: 1,
#   counter: 1,
#   toiletries: 1,
#   sink: 1,
#   items: 1,
#   bathroom: 1,
#   hygiene: 1,
#   clock: 1,
#   bicycle: 1,
#   metal: 1,
#   wheel: 1,
#   bench: 1,
#   cars: 1,
#   street: 1,
#   City: 1,
#   man: 1,
#   bench: 1,
#   water: 1,
#   wheelchair: 1,
#   buildings: 1,
#   riders: 1,
#   group: 1,
#   motorcycle: 1,
#   grass: 1,
#   city: 1,
#   middle: 1,
#   horse: 1,
#   top: 1,
#   cake: 1,
#   coconuts: 1,
#   Half: 1,
#   kitty: 1,
#   top: 1,
#   toilet: 1,
#   cover: 1,
#   liner: 1,
#   distance: 1,
#   Jet: 1,
#   day: 1,
#   windows: 1,
#   car: 1,
#   heads: 1,
#   Dogs: 1,
#   person: 1,
#   patch: 1,
#   scenery: 1,
#   grass: 1,
#   picture: 1,
#   kitchen: 1,
#   violin: 1,
#   man: 1,
#   door: 1,
#   door: 1,
#   cat: 1,
#   sticker: 1,
#   group: 1,
#   people: 1,
#   mopeds: 1,
#   street: 1,
#   car: 1,
#   surfboard: 1,
#   road: 1,
#   top: 1,
#   wheels: 1,
#   landing: 1,
#   landing: 1,
#   airplane: 1,
#   giraffe: 1,
#   top: 1,
#   head: 1,
#   birds: 1,
#   bus: 1,
#   bus: 1,
#   stop: 1,
#   People: 1,
#   drinking: 1,
#   cat: 1,
#   toilet: 1,
#   water: 1,
#   people: 1,
#   skiing: 1,
#   country: 1,
#   snow: 1,
#   kitchen: 1,
#   stuff: 1,
#   stove: 1,
#   sink: 1,
#   dogs: 1,
#   driver: 1,
#   woman: 1,
#   seat: 1,
#   man: 1,
#   spoon: 1,
#   pot: 1,
#   food: 1,
#   toilet: 1,
#   window: 1,
#   shower: 1,
#   front: 1,
#   city: 1,
#   dog: 1,
#   woman: 1,
#   street: 1,
#   estate: 1,
#   ad: 1,
#   wood: 1,
#   kitchen: 1,
#   shower: 1,
#   map: 1,
#   bathroom: 1,
#   curtain: 1,
#   sidewalk: 1,
#   couple: 1,
#   cars: 1,
#   street: 1,
#   dog: 1,
#   fence: 1,
#   noses: 1,
#   goat: 1,
#   kitchen: 1,
#   door: 1,
#   cupboard: 1,
#   man: 1,
#   bikes: 1,
#   street: 1,
#   cars: 1,
#   People: 1,
#   chain: 1,
#   man: 1,
#   bike: 1,
#   fence: 1,
#   bike: 1,
#   fence: 1,
#   water: 1,
#   metal: 1,
#   face: 1,
#   person: 1,
#   toilet: 1,
#   bowl: 1,
#   board: 1,
#   skate: 1,
#   person: 1,
#   field: 1,
#   cake: 1,
#   plate: 1,
#   dessert: 1,
#   cake: 1,
#   vanity: 1,
#   sinks: 1,
#   mirrors: 1,
#   sink: 1,
#   water: 1,
#   drink: 1,
#   man: 1,
#   fountain: 1,
#   lot: 1,
#   motorbikes: 1,
#   street: 1,
#   line: 1,
#   store: 1,
#   outside: 1,
#   restaurant: 1,
#   sign: 1,
#   Kitty: 1,
#   Hello: 1,
#   toilet: 1,
#   symbol: 1,
#   picture: 1,
#   urinals: 1,
#   wall: 1,
#   woman: 1,
#   street: 1,
#   man: 1,
#   bench: 1,
#   bike: 1,
#   crowd: 1,
#   people: 1,
#   bus: 1,
#   city: 1,
#   counter: 1,
#   vegetables: 1,
#   board: 1,
#   knife: 1,
#   advertisement: 1,
#   truck: 1,
#   Entourage: 1,
#   delivery: 1,
#   man: 1,
#   forest: 1,
#   man: 1,
#   skiing: 1,
#   area: 1,
#   stove: 1,
#   kitchen: 1,
#   sink: 1,
#   motorcycle: 1,
#   toddler: 1,
#   lot: 1,
#   parking: 1,
#   ad: 1,
#   van: 1,
#   show: 1,
#   television: 1,
#   desk: 1,
#   factory: 1,
#   machinery: 1,
#   Women: 1,
#   motorcycle: 1,
#   man: 1,
#   houses: 1,
#   street: 1,
#   bathroom: 1,
#   toilette: 1,
#   face: 1,
#   poster: 1,
#   street: 1,
#   traffic: 1,
#   city: 1,
#   People: 1,
#   toilet: 1,
#   brush: 1,
#   paper: 1,
#   toilet: 1,
#   toilet: 1,
#   wall: 1,
#   bathroom: 1,
#   plastic: 1,
#   flock: 1,
#   top: 1,
#   birds: 1,
#   giraffe: 1,
#   heads: 1,
#   car: 1,
#   dogs: 1,
#   windows: 1,
#   park: 1,
#   woman: 1,
#   purse: 1,
#   bench: 1,
#   dog: 1,
#   sheep: 1,
#   pen: 1,
#   sheep: 1,
#   alley: 1,
#   man: 1,
#   horse: 1,
#   costume: 1,
#   Virgin: 1,
#   tarmac: 1,
#   airline: 1,
#   Australia: 1,
#   items: 1,
#   room: 1,
#   living: 1,
#   fireplace: 1,
#   skateboard: 1,
#   child: 1,
#   field: 1,
#   grass: 1,
#   computer: 1,
#   corner: 1,
#   desk: 1,
#   window: 1,
#   toilet: 1,
#   items: 1,
#   top: 1,
#   bathroom.with: 1,
#   city: 1,
#   Motorists: 1,
#   bicyclists: 1,
#   square: 1,
#   window: 1,
#   car: 1,
#   head: 1,
#   dogs: 1,
#   fireplace: 1,
#   variety: 1,
#   pots: 1,
#   nook: 1,
#   lot: 1,
#   horses: 1,
#   parking: 1,
#   grass: 1,
#   figurine: 1,
#   wheel: 1,
#   clock: 1,
#   bicycle: 1,
#   photo: 1,
#   women: 1,
#   set: 1,
#   work: 1,
#   toilet: 1,
#   toilet: 1,
#   bathroom: 1,
#   floor: 1,
#   bicycle: 1,
#   wheel: 1,
#   appearance: 1,
#   clock: 1,
#   plungers: 1,
#   toilet: 1,
#   tiles: 1,
#   stall: 1,
#   advertisement: 1,
#   truck: 1,
#   side: 1,
#   delivery: 1,
#   restroom: 1,
#   toilet: 1,
#   toilet: 1,
#   seat: 1,
#   group: 1,
#   people: 1,
#   kitchen: 1,
#   food: 1,
#   parking: 1,
#   way: 1,
#   signs: 1,
#   garage: 1,
#   filling: 1,
#   shavings: 1,
#   cake: 1,
#   creme: 1,
#   umbrella: 1,
#   woman: 1,
#   neighborhood: 1,
#   city: 1,
#   city: 1,
#   dog: 1,
#   woman: 1,
#   sidewalk: 1,
#   plane: 1,
#   Virgin: 1,
#   airplane: 1,
#   background: 1,
#   Group: 1,
#   vegetables: 1,
#   people: 1,
#   line: 1,
#   city: 1,
#   traffic: 1,
#   street: 1,
#   bicycles: 1,
#   bed: 1,
#   man: 1,
#   bicycle: 1,
#   truck: 1,
#   sky: 1,
#   people: 1,
#   Group: 1,
#   sailing: 1,
#   table: 1,
#   liquid: 1,
#   jar: 1,
#   Fruit: 1,
#   bathroom: 1,
#   items: 1,
#   sink: 1,
#   care: 1,
#   station: 1,
#   office: 1,
#   use: 1,
#   work: 1,
#   airplane: 1,
#   MT: 1,
#   sky: 1,
#   letters: 1,
#   screens: 1,
#   scene: 1,
#   computer: 1,
#   beach: 1,
#   street: 1,
#   group: 1,
#   motorcyclists: 1,
#   city: 1,
#   top: 1,
#   Elephants: 1,
#   line: 1,
#   people: 1,
#   males: 1,
#   store: 1,
#   bicycle: 1,
#   bike: 1,
#   cabinets: 1,
#   kitchen: 1,
#   appliances: 1,
#   apartment: 1,
#   city: 1,
#   bus: 1,
#   area: 1,
#   People: 1,
#   turn: 1,
#   dirt: 1,
#   riders: 1,
#   bike: 1,
#   light: 1,
#   stop: 1,
#   truck: 1,
#   weather: 1,
#   desk: 1,
#   papers: 1,
#   computer: 1,
#   library: 1,
#   workstation: 1,
#   notebook: 1,
#   papers: 1,
#   computer: 1,
#   sign: 1,
#   Bicycle: 1,
#   welcome: 1,
#   Scotland: 1,
#   sheep: 1,
#   noses: 1,
#   fence: 1,
#   dog: 1,
#   street: 1,
#   city: 1,
#   cars: 1,
#   pedestrians: 1,
#   bowl: 1,
#   table: 1,
#   dining: 1,
#   cloves: 1,
#   bathroom: 1,
#   phase: 1,
#   reconstruction: 1,
#   middle: 1,
#   kitchen: 1,
#   granite: 1,
#   woman: 1,
#   counters: 1,
#   car: 1,
#   heads: 1,
#   dogs: 1,
#   window: 1,
#   street: 1,
#   people: 1,
#   traffic: 1,
#   photograph: 1,
#   desk: 1,
#   monitor: 1,
#   accesories: 1,
#   Computer: 1,
#   snow: 1,
#   group: 1,
#   slope: 1,
#   people: 1,
#   kitchen: 1,
#   people: 1,
#   pizza: 1,
#   pointing: 1,
#   wall: 1,
#   restroom: 1,
#   doorway: 1,
#   floor: 1,
#   people: 1,
#   snow: 1,
#   equipment: 1,
#   field: 1,
#   people: 1,
#   aprons: 1,
#   hats: 1,
#   vegetables: 1,
#   screen: 1,
#   person: 1,
#   picture: 1,
#   TV: 1,
#   Group: 1,
#   kites: 1,
#   people: 1,
#   beach: 1,
#   kitchen: 1,
#   juicer: 1,
#   table: 1,
#   vegetable: 1,
#   sinks: 1,
#   toilette: 1,
#   bathroom: 1,
#   mirrors: 1,
#   bicycle: 1,
#   flood: 1,
#   fence: 1,
#   waters: 1,
#   screens: 1,
#   computer: 1,
#   desk: 1,
#   screen: 1,
#   row: 1,
#   park: 1,
#   side: 1,
#   hill: 1,
#   sculpture: 1,
#   rod: 1,
#   city: 1,
#   sidewalk: 1,
#   bathroom: 1,
#   closet: 1,
#   view: 1,
#   walk: 1,
#   road: 1,
#   parking: 1,
#   signs: 1,
#   garage: 1,
#   staff: 1,
#   Restaurant: 1,
#   bar: 1,
#   break: 1,
#   fighter: 1,
#   sky: 1,
#   smoke: 1,
#   jet: 1,
#   person: 1,
#   motorcycle: 1,
#   jump: 1,
#   stunt: 1,
#   shop: 1,
#   customer: 1,
#   bike: 1,
#   employee: 1,
#   motor: 1,
#   shrub: 1,
#   BMW: 1,
#   cycle: 1,
#   group: 1,
#   bunch: 1,
#   people: 1,
#   doughnuts: 1,
#   airplane: 1,
#   flight: 1,
#   photograph: 1,
#   window: 1,
#   items: 1,
#   kitchenette: 1,
#   top: 1,
#   counter: 1,
#   store: 1,
#   boy: 1,
#   man: 1,
#   bicycle: 1,
#   group: 1,
#   people: 1,
#   vegetables: 1,
#   line: 1,
#   jacuzzi: 1,
#   closet: 1,
#   bathroom: 1,
#   tub: 1,
#   closet: 1,
#   walk: 1,
#   bathroom: 1,
#   in: 1,
#   show: 1,
#   motorcycle: 1,
#   model: 1,
#   motorbike: 1,
#   standing: 1,
#   helmet: 1,
#   person: 1,
#   motorcycle: 1,
#   cafeteria: 1,
#   kitchen: 1,
#   use: 1,
#   type: 1,
#   biplane: 1,
#   sky: 1,
#   tricks: 1,
#   smoke: 1,
#   buggy: 1,
#   automobiles: 1,
#   display: 1,
#   dune: 1,
#   beach: 1,
#   motorcyclist: 1,
#   motorcycle: 1,
#   lookout: 1,
#   picture: 1,
#   bathroom: 1,
#   woman: 1,
#   mirror: 1,
#   bikers: 1,
#   track: 1,
#   Dirt: 1,
#   corner: 1,
#   control: 1,
#   stall: 1,
#   toilet: 1,
#   buttons: 1,
#   front: 1,
#   steps: 1,
#   trick: 1,
#   Skateboarder: 1,
#   flooding: 1,
#   bicycle: 1,
#   man: 1,
#   waters: 1,
#   adults: 1,
#   snow: 1,
#   group: 1,
#   children: 1,
#   woman: 1,
#   mirror: 1,
#   picture: 1,
#   bathroom: 1,
#   racers: 1,
#   bike: 1,
#   track: 1,
#   Motor: 1,
#   kitchen: 1,
#   pots: 1,
#   stove: 1,
#   pots: 1,
#   walls: 1,
#   kitchen: 1,
#   counters: 1,
#   steel: 1,
#   drivers: 1,
#   man: 1,
#   seat: 1,
#   truck: 1,
#   group: 1,
#   people: 1,
#   slope: 1,
#   mountain: 1,
#   mirror: 1,
#   front: 1,
#   woman: 1,
#   picture: 1,
#   street: 1,
#   picture: 1,
#   night: 1,
#   overview: 1,
#   women: 1,
#   rack: 1,
#   bus: 1,
#   bicycles: 1,
#   road: 1,
#   side: 1,
#   motorcycles: 1,
#   people: 1,
#   signs: 1,
#   parking: 1,
#   front: 1,
#   garage: 1,
#   street: 1,
#   row: 1,
#   series: 1,
#   motorbikes: 1,
#   couple: 1,
#   house: 1,
#   food: 1,
#   kitchen: 1,
#   Individuals: 1,
#   pastries: 1,
#   kind: 1,
#   donuts: 1,
#   picture: 1,
#   car: 1,
#   water: 1,
#   boat: 1,
#   bathroom: 1,
#   floor: 1,
#   cat: 1,
#   sink: 1,
#   street: 1,
#   person: 1,
#   scene: 1,
#   vehicles: 1,
#   gas: 1,
#   picture: 1,
#   range: 1,
#   figurines: 1,
#   cars: 1,
#   scene: 1,
#   street: 1,
#   bus: 1,
#   plane: 1,
#   smoke: 1,
#   trail: 1,
#   air: 1,
#   street: 1,
#   person: 1,
#   middle: 1,
#   skis: 1,
#   cars: 1,
#   city: 1,
#   street: 1,
#   bus: 1,
#   food: 1,
#   couple: 1,
#   people: 1,
#   kitchen: 1,
#   train: 1,
#   nature: 1,
#   track: 1,
#   park: 1,
#   teddy: 1,
#   associate: 1,
#   bear: 1,
#   office: 1,
#   mountain: 1,
#   airplane: 1,
#   wing: 1,
#   range: 1,
#   streetlights: 1,
#   intersection: 1,
# ...
#   boy: 1,
#   kitchen: 1,
#   cupboards: 1,
#   appliances: 1,
#   lots: 1,
#   dishes: 1,
#   cat: 1,
#   bathroom: 1,
#   top: 1,
#   seat: 1,
#   toilet: 1,
#   desktop: 1,
#   computer: 1,
#   laptop: 1,
#   office: 1,
#   computer: 1,
#   bathroom: 1,
#   curtain: 1,
#   towel: 1,
#   sink: 1,
#   mirror: 1,
#   windows: 1,
#   building: 1,
#   heritage: 1,
#   tower: 1,
#   clock: 1,
#   top: 1,
#   man: 1,
#   mannequin: 1,
#   woman: 1,
#   jacket: 1,
#   rider: 1,
#   bike: 1,
#   Dirt: 1,
#   trees: 1,
#   path: 1,
#   sunglasses: 1,
#   helmet: 1,
#   sidecar: 1,
#   dog: 1,
#   motorcycle: 1,
#   Mercedes: 1,
#   top: 1,
#   cargo: 1,
#   train: 1,
#   Benz: 1,
#   sink: 1,
#   scale: 1,
#   bathroom: 1,
#   toilet: 1,
#   towel: 1,
#   woman: 1,
#   fence: 1,
#   front: 1,
#   horse: 1,
#   car: 1,
#   cake: 1,
#   car: 1,
#   candles: 1,
#   boy: 1,
#   birthday: 1,
#   street: 1,
#   city: 1,
#   bikes: 1,
#   people: 1,
#   bus: 1,
#   officers: 1,
#   Police: 1,
#   city: 1,
#   bikes: 1,
#   night: 1,
#   kitchen: 1,
#   lights: 1,
#   cabinet: 1,
#   dinner: 1,
#   Man: 1,
#   people: 1,
#   room: 1,
#   table: 1,
#   bicycle: 1,
#   ladder: 1,
#   row: 1,
#   racers: 1,
#   bike: 1,
#   dirt: 1,
#   group: 1,
#   man: 1,
#   pocket: 1,
#   blazer: 1,
#   bottle: 1,
#   kitchen: 1,
#   walks: 1,
#   front: 1,
#   horse: 1,
#   woman: 1,
#   car: 1,
#   tile: 1,
#   sink: 1,
#   toilet: 1,
#   bathroom: 1,
#   flooring: 1,
#   stove: 1,
#   kitchen: 1,
#   top: 1,
#   things: 1,
#   dishes: 1,
#   side: 1,
#   car: 1,
#   street: 1,
#   bus: 1,
#   city: 1,
#   sink: 1,
#   towels: 1,
#   Bathroom: 1,
#   shower: 1,
#   toilet: 1,
#   horse: 1,
#   Lady: 1,
#   wire: 1,
#   front: 1,
#   fence: 1,
#   lake: 1,
#   side: 1,
#   bike: 1,
#   man: 1,
#   road: 1,
#   lot: 1,
#   dirt: 1,
#   motorcycles: 1,
#   bikers: 1,
#   group: 1,
#   containers: 1,
#   chef: 1,
#   jars: 1,
#   counter: 1,
#   kitchen: 1,
#   vanity: 1,
#   bathroom: 1,
#   walls: 1,
#   toilet: 1,
#   sink: 1,
#   shelf: 1,
#   painting: 1,
#   decorations: 1,
#   room: 1,
#   wall: 1,
#   wall: 1,
#   building: 1,
#   stone: 1,
#   restroom: 1,
#   outside: 1,
#   windows: 1,
#   side: 1,
#   side: 1,
#   images: 1,
#   bathroom: 1,
#   board: 1,
#   counter: 1,
#   front: 1,
#   tongs: 1,
#   cook: 1,
#   track: 1,
#   road: 1,
#   train: 1,
#   train: 1,
#   commuter: 1,
#   run: 1,
#   port: 1,
#   air: 1,
#   plane: 1,
#   way: 1,
#   city: 1,
#   people: 1,
#   background: 1,
#   buildings: 1,
#   street: 1,
#   walls: 1,
#   kitchen: 1,
#   country: 1,
#   flooring: 1,
#   wood: 1,
#   kitchen: 1,
#   machines: 1,
#   chef: 1,
#   bowls: 1,
#   jars: 1,
#   curtain: 1,
#   shower: 1,
#   bathroom: 1,
#   bathtub: 1,
#   toilet: 1,
#   soldier: 1,
#   jacket: 1,
#   picture: 1,
#   brazier: 1,
#   lady: 1,
#   kitchen: 1,
#   counter: 1,
#   Foods: 1,
#   Whole: 1,
#   bag: 1,
#   furniture: 1,
#   item: 1,
#   terminal: 1,
#   bedroom: 1,
#   computer: 1,
#   tower: 1,
#   clock: 1,
#   church: 1,
#   door: 1,
#   church: 1,
#   taxi: 1,
#   way: 1,
#   jet: 1,
#   Ryanair: 1,
#   airport: 1,
#   street: 1,
#   man: 1,
#   bike: 1,
#   phone: 1,
#   cell: 1,
#   drawers: 1,
#   room: 1,
#   chest: 1,
#   television: 1,
#   bed: 1,
#   living: 1,
#   chair: 1,
#   TV: 1,
#   screen: 1,
#   room: 1,
#   boy: 1,
#   cake: 1,
#   birthday: 1,
#   table: 1,
#   racecar: 1,
#   officer: 1,
#   police: 1,
#   cars: 1,
#   street: 1,
#   city: 1,
#   shop: 1,
#   motorcycles: 1,
#   row: 1,
#   donut: 1,
#   street: 1,
#   top: 1,
#   windows: 1,
#   face: 1,
#   building: 1,
#   clock: 1,
#   rowers: 1,
#   team: 1,
#   water: 1,
#   body: 1,
#   canoe: 1,
#   woman: 1,
#   trophy: 1,
#   man: 1,
#   motorcycle: 1,
#   front: 1,
#   jets: 1,
#   tarmac: 1,
#   fighter: 1,
#   airport: 1,
#   group: 1,
#   motorcycle: 1,
#   sport: 1,
#   wall: 1,
#   graffiti: 1,
#   front: 1,
#   sinks: 1,
#   bathroom: 1,
#   tubs: 1,
#   room: 1,
#   bath: 1,
#   ...},
#  'Rest': {stove: 1,
#   gas: 1,
#   countertop: 1,
#   sink: 1,
#   kitchen: 1,
#   steel: 1,
#   equipment: 1,
#   office: 1,
#   space: 1,
#   Office: 1,
#   top: 1,
#   desk: 1,
#   counter: 1,
#   marble: 1,
#   fridge: 1,
#   steel: 1,
#   kitchen: 1,
#   tops: 1,
#   laptop: 1,
#   scanner: 1,
#   office: 1,
#   home: 1,
#   monitor: 1,
#   printer: 1,
#   stall: 1,
#   paper: 1,
#   toilet: 1,
#   toilet: 1,
#   rolls: 1,
#   brush: 1,
#   toilet: 1,
#   stool: 1,
#   vanity: 1,
#   room: 1,
#   mirrors: 1,
#   bath: 1,
#   lights: 1,
#   basins: 1,
#   sink: 1,
#   marble: 1,
#   rider: 1,
#   bike: 1,
#   dirt: 1,
#   air: 1,
#   jump: 1,
#   stunt: 1,
#   sign: 1,
#   restaurant: 1,
#   Reaffaello: 1,
#   Italian: 1,
#   building: 1,
#   front: 1,
#   bathroom: 1,
#   sink: 1,
#   basin: 1,
#   products: 1,
#   cabinets: 1,
#   vanity: 1,
#   door: 1,
#   end: 1,
#   cat: 1,
#   painting: 1,
#   cat: 1,
#   door: 1,
#   wall: 1,
#   bathroom: 1,
#   White: 1,
#   poster: 1,
#   tiles: 1,
#   line: 1,
#   bathroom: 1,
#   sink: 1,
#   window: 1,
#   cabinet: 1,
#   medicine: 1,
#   toilet: 1,
#   desk: 1,
#   view: 1,
#   screens: 1,
#   computer: 1,
#   ocean: 1,
#   show: 1,
#   sight: 1,
#   Mans: 1,
#   plunger: 1,
#   basket: 1,
#   trash: 1,
#   fixtures: 1,
#   shot: 1,
#   refrigerator: 1,
#   microwave: 1,
#   kitchen: 1,
#   dishwasher: 1,
#   sink: 1,
#   parking: 1,
#   front: 1,
#   grass: 1,
#   mules: 1,
#   lot: 1,
#   hotel: 1,
#   front: 1,
#   cat: 1,
#   wheel: 1,
#   scratcher: 1,
#   bicycle: 1,
#   cat: 1,
#   mirrors: 1,
#   racks: 1,
#   towel: 1,
#   sinks: 1,
#   toilet: 1,
#   bathroom: 1,
#   pan: 1,
#   cookies: 1,
#   cookies: 1,
#   counter: 1,
#   pan: 1,
#   stove: 1,
#   cabinet: 1,
#   area: 1,
#   kitchen: 1,
#   man: 1,
#   container: 1,
#   item: 1,
#   floor: 1,
#   place: 1,
#   fir: 1,
#   bench: 1,
#   baskets: 1,
#   room: 1,
#   background: 1,
#   cover: 1,
#   seat: 1,
#   toilet: 1,
#   bowl: 1,
#   Kitty: 1,
#   toilet: 1,
#   Hello: 1,
#   room: 1,
#   supply: 1,
#   craft: 1,
#   supplies: 1,
#   containers: 1,
#   craft: 1,
#   hood: 1,
#   car: 1,
#   man: 1,
#   logo: 1,
#   race: 1,
#   sox: 1,
#   lamps: 1,
#   street: 1,
#   light: 1,
#   air: 1,
#   Man: 1,
#   night: 1,
#   snow: 1,
#   people: 1,
#   children: 1,
#   helmets: 1,
#   adults: 1,
#   skis: 1,
#   man: 1,
#   bike: 1,
#   water: 1,
#   flood: 1,
#   calf: 1,
#   shorts: 1,
#   car: 1,
#   seat: 1,
#   driver: 1,
#   sign: 1,
#   picture: 1,
#   stop: 1,
#   barriers: 1,
#   corner: 1,
#   track: 1,
#   racers: 1,
#   bike: 1,
#   Dirt: 1,
#   tablet: 1,
#   computer: 1,
#   desk: 1,
#   Mac: 1,
#   computer: 1,
#   iphone: 1,
#   ramp: 1,
#   boarding: 1,
#   tarmac: 1,
#   airport: 1,
#   Sunrise: 1,
#   plane: 1,
#   scooter: 1,
#   rides: 1,
#   motor: 1,
#   bus: 1,
#   front: 1,
#   car: 1,
#   bear: 1,
#   work: 1,
#   teddy: 1,
#   size: 1,
#   woman: 1,
#   life: 1,
#   set: 1,
#   clock: 1,
#   stove: 1,
#   stove: 1,
#   rack: 1,
#   spice: 1,
#   car: 1,
#   man: 1,
#   hat: 1,
#   fedora: 1,
#   tie: 1,
#   bow: 1,
#   parking: 1,
#   airport: 1,
#   horizon: 1,
#   sun: 1,
#   scene: 1,
#   lot: 1,
#   tie: 1,
#   bow: 1,
#   car: 1,
#   man: 1,
#   head: 1,
#   hat: 1,
#   rack: 1,
#   room: 1,
#   Entertainment: 1,
#   area: 1,
#   seating: 1,
#   tv: 1,
#   dvds: 1,
#   tops: 1,
#   counter: 1,
#   oven: 1,
#   top: 1,
#   stove: 1,
#   kitchen: 1,
#   oranges: 1,
#   spirits: 1,
#   bottle: 1,
#   pillows: 1,
#   tapestry: 1,
#   accents: 1,
#   flowers: 1,
#   home: 1,
#   bowl: 1,
#   glass: 1,
#   decor: 1,
#   lot: 1,
#   dog: 1,
#   parking: 1,
#   motorcycle: 1,
#   car: 1,
#   side: 1,
#   snow: 1,
#   people: 1,
#   covering: 1,
#   carasel: 1,
#   resort: 1,
#   snow: 1,
#   flowers: 1,
#   fruit: 1,
#   pillow: 1,
#   Bowl: 1,
#   gold: 1,
#   liqour: 1,
#   bottle: 1,
#   kitchen: 1,
#   crafts: 1,
#   toy: 1,
#   phone: 1,
#   table: 1,
#   counter: 1,
#   bear: 1,
#   teddy: 1,
#   hat: 1,
#   table: 1,
#   building: 1,
#   building: 1,
#   ladder: 1,
#   bowl: 1,
#   toilet: 1,
#   dog: 1,
#   person: 1,
#   room: 1,
#   living: 1,
#   tv: 1,
#   chairs: 1,
#   couches: 1,
#   screen: 1,
#   front: 1,
#   table: 1,
#   bowl: 1,
#   tank: 1,
#   fish: 1,
#   cat: 1,
#   exhibit: 1,
#   studio: 1,
#   car: 1,
#   prop: 1,
#   Wheels: 1,
#   Hot: 1,
#   winter: 1,
#   country: 1,
#   person: 1,
#   town: 1,
#   street: 1,
#   skiing: 1,
#   curb: 1,
#   man: 1,
#   ticket: 1,
#   cop: 1,
#   motor: 1,
#   scene: 1,
#   motorcycle: 1,
#   bike: 1,
#   bag: 1,
#   girl: 1,
#   DSW: 1,
#   guy: 1,
#   bathroom: 1,
#   shower: 1,
#   toilette: 1,
#   mirror: 1,
#   vanity: 1,
#   sink: 1,
#   kitchen: 1,
#   woman: 1,
#   man: 1,
#   woman: 1,
#   motorcycle: 1,
#   bag: 1,
#   DSW: 1,
#   road: 1,
#   country: 1,
#   bike: 1,
#   dirt: 1,
#   forest: 1,
#   man: 1,
#   parade: 1,
#   community: 1,
#   pride: 1,
#   Gay: 1,
#   street: 1,
#   motorcycles: 1,
#   members: 1,
#   meter: 1,
#   SUPABAAD: 1,
#   parking: 1,
#   plate: 1,
#   license: 1,
#   car: 1,
#   Red: 1,
#   car: 1,
#   Sox: 1,
#   boy: 1,
#   visor: 1,
#   shirt: 1,
#   Red: 1,
#   Sox: 1,
#   dog: 1,
#   group: 1,
#   bench: 1,
#   park: 1,
#   leash: 1,
#   people: 1,
#   girl: 1,
#   booster: 1,
#   dishes: 1,
#   kitchen: 1,
#   washing: 1,
#   stool: 1,
#   toilet: 1,
#   items: 1,
#   bathroom: 1,
#   bathroom: 1,
#   sink: 1,
#   cover: 1,
#   road: 1,
#   crossing: 1,
#   Elephant: 1,
#   vehicle: 1,
#   SUV: 1,
#   front: 1,
#   animal: 1,
#   stuff: 1,
#   leather: 1,
#   person: 1,
#   back: 1,
#   motorcycle: 1,
#   couple: 1,
#   bikes: 1,
#   motocross: 1,
#   people: 1,
#   couple: 1,
#   people: 1,
#   floor: 1,
#   wall: 1,
#   cement: 1,
#   frame: 1,
#   door: 1,
#   bathroom: 1,
#   car: 1,
#   foliage: 1,
#   fall: 1,
#   sign: 1,
#   Picture: 1,
#   stop: 1,
#   pictures: 1,
#   couch: 1,
#   lamp: 1,
#   television: 1,
#   style: 1,
#   retro: 1,
#   curtains: 1,
#   front: 1,
#   camera: 1,
#   woman: 1,
#   teeth: 1,
#   background: 1,
#   person: 1,
#   woman: 1,
#   portrait: 1,
#   vases: 1,
#   wall: 1,
#   room: 1,
#   clock: 1,
#   lady: 1,
#   hand: 1,
#   man: 1,
#   phone: 1,
#   cell: 1,
#   ledge: 1,
#   window: 1,
#   phone: 1,
#   window: 1,
#   kitchen: 1,
#   man: 1,
#   sill: 1,
#   perches: 1,
#   desktop: 1,
#   computer: 1,
#   laptop: 1,
#   desk: 1,
#   office: 1,
#   computer: 1,
#   clock: 1,
#   oven: 1,
#   knob: 1,
#   control: 1,
#   top: 1,
#   stove: 1,
#   park: 1,
#   bench: 1,
#   park: 1,
#   grass: 1,
#   porch: 1,
#   front: 1,
#   shop: 1,
#   donuts: 1,
#   motorcycles: 1,
#   group: 1,
#   side: 1,
#   front: 1,
#   side: 1,
#   computers: 1,
#   walls: 1,
#   flags: 1,
#   sports: 1,
#   cubicle: 1,
#   desks: 1,
#   restroom: 1,
#   side: 1,
#   toilet: 1,
#   sink: 1,
#   object: 1,
#   toilet: 1,
#   computer: 1,
#   desktop: 1,
#   desk: 1,
#   mouse: 1,
#   keyboard: 1,
#   monitors: 1,
#   fence: 1,
#   front: 1,
#   horse: 1,
#   wire: 1,
#   woman: 1,
#   razor: 1,
#   toilet: 1,
#   bathroom: 1,
#   bureau: 1,
#   rack: 1,
#   door: 1,
#   shower: 1,
#   hotel: 1,
#   tv: 1,
#   bed: 1,
#   screen: 1,
#   chair: 1,
#   room: 1,
#   officers: 1,
#   civilians: 1,
#   banquet: 1,
#   Navy: 1,
#   officers: 1,
#   pair: 1,
#   cake: 1,
#   tarmac: 1,
#   rest: 1,
#   airplanes: 1,
#   airport: 1,
#   jet: 1,
#   pair: 1,
#   Diners: 1,
#   street: 1,
#   city: 1,
#   table: 1,
#   patio: 1,
#   restaurant: 1,
#   cat: 1,
#   calico: 1,
#   water: 1,
#   bathroom: 1,
#   drinking: 1,
#   tap: 1,
#   head: 1,
#   metal: 1,
#   mirror: 1,
#   compartment: 1,
#   vanity: 1,
#   utilities: 1,
#   photos: 1,
#   corner: 1,
#   room: 1,
#   living: 1,
#   playing: 1,
#   television: 1,
#   family: 1,
#   paintings: 1,
#   fireplace: 1,
#   pictures: 1,
#   table: 1,
#   dining: 1,
#   magnets: 1,
#   refrigerator: 1,
#   kitchen: 1,
#   counters: 1,
#   chairs: 1,
#   candle: 1,
#   metal: 1,
#   person: 1,
#   table: 1,
#   kitchen: 1,
#   spoon: 1,
#   image: 1,
#   farm: 1,
#   computer: 1,
#   children: 1,
#   woman: 1,
#   man: 1,
#   Chef: 1,
#   items: 1,
#   bar: 1,
#   food: 1,
#   kitchen: 1,
#   people: 1,
#   kitchen: 1,
#   home: 1,
#   refrigerator: 1,
#   pictures: 1,
#   lots: 1,
#   cards: 1,
#   bathroom: 1,
#   foot: 1,
#   flooring: 1,
#   claw: 1,
#   toilet: 1,
#   wood: 1,
#   side: 1,
#   hood: 1,
#   bear: 1,
#   teddy: 1,
#   vehicle: 1,
#   Chevrolet: 1,
#   restroom: 1,
#   toilet: 1,
#   dispenser: 1,
#   paper: 1,
#   toilet: 1,
#   stall: 1,
#   floors: 1,
#   refrigerator: 1,
#   steel: 1,
#   tile: 1,
#   kitchen: 1,
#   counters: 1,
#   granite: 1,
#   computers: 1,
#   desk: 1,
#   office: 1,
#   books: 1,
#   phone: 1,
#   paper: 1,
#   show: 1,
#   engine: 1,
#   open: 1,
#   hood: 1,
#   bear: 1,
#   well: 1,
#   teddy: 1,
#   car: 1,
#   bathroom: 1,
#   sink: 1,
#   tub: 1,
#   bath: 1,
#   style: 1,
#   jacuzzi: 1,
#   dirt: 1,
#   middle: 1,
#   rider: 1,
#   Motorcycle: 1,
#   air: 1,
#   bike: 1,
#   refrigerator: 1,
#   kitchen: 1,
#   View: 1,
#   stuff: 1,
#   rooms: 1,
#   Lot: 1,
#   breakfast: 1,
#   sink: 1,
#   dishes: 1,
#   jeans: 1,
#   glasses: 1,
#   ocean: 1,
#   sun: 1,
#   person: 1,
#   rock: 1,
#   mirror: 1,
#   shower: 1,
#   walk: 1,
#   toilet: 1,
#   bathroom: 1,
#   sink: 1,
#   country: 1,
#   nacks: 1,
#   kitchen: 1,
#   greenery: 1,
#   type: 1,
#   charm: 1,
#   coffee: 1,
#   cups: 1,
#   maker: 1,
#   Tow: 1,
#   coffee: 1,
#   front: 1,
#   cup: 1,
#   highway: 1,
#   cars: 1,
#   side: 1,
#   airplane: 1,
#   jet: 1,
#   group: 1,
#   sky: 1,
#   road: 1,
#   back: 1,
#   dog: 1,
#   basket: 1,
#   bike: 1,
#   motor: 1,
#   spots: 1,
#   men: 1,
#   scene: 1,
#   street: 1,
#   city: 1,
#   benches: 1,
#   park: 1,
#   uniform: 1,
#   nurses: 1,
#   setups: 1,
#   bed: 1,
#   display: 1,
#   Hospital: 1,
#   bathroom: 1,
#   warehouse: 1,
#   toilets: 1,
#   tubs: 1,
#   sinks: 1,
#   items: 1,
#   Rue: 1,
#   buildings: 1,
#   Paul: 1,
#   Saint: 1,
#   Rue: 1,
#   corner: 1,
#   Bonsecours: 1,
#   statues: 1,
#   baggage: 1,
#   airport: 1,
#   ground: 1,
#   Airlines: 1,
#   cars: 1,
#   China: 1,
#   wood: 1,
#   front: 1,
#   cat: 1,
#   books: 1,
#   library: 1,
#   floor: 1,
#   artwork: 1,
#   piece: 1,
#   seat: 1,
#   room: 1,
#   toilet: 1,
#   art: 1,
#   ceiling: 1,
#   hooks: 1,
#   spoons: 1,
#   kitchen: 1,
#   pans: 1,
#   rack: 1,
#   animal: 1,
#   hood: 1,
#   area: 1,
#   wit: 1,
#   engine: 1,
#   car: 1,
#   washing: 1,
#   hand: 1,
#   set: 1,
#   bathroom: 1,
#   sinks: 1,
#   store: 1,
#   air: 1,
#   way: 1,
#   plane: 1,
#   air: 1,
#   run: 1,
#   port: 1,
#   sink: 1,
#   shower: 1,
#   porcelain: 1,
#   bathroom: 1,
#   front: 1,
#   space: 1,
#   counter: 1,
#   tub: 1,
#   curtain: 1,
#   rack: 1,
#   utility: 1,
#   shower: 1,
#   toilet: 1,
#   door: 1,
#   bathroom: 1,
#   cabinets: 1,
#   wood: 1,
#   kitchen: 1,
#   view: 1,
#   kitchen: 1,
#   Home: 1,
#   top: 1,
#   man: 1,
#   side: 1,
#   waits: 1,
#   stairs: 1,
#   train: 1,
#   dispenser: 1,
#   restroom: 1,
#   soap: 1,
#   towel: 1,
#   paper: 1,
#   sinks: 1,
#   nurse: 1,
#   beds: 1,
#   hospital: 1,
#   mannequin: 1,
#   patients: 1,
#   uniform: 1,
#   flower: 1,
#   reading: 1,
#   phone: 1,
#   men: 1,
#   benches: 1,
#   park: 1,
#   bed: 1,
#   vest: 1,
#   reflector: 1,
#   outfit: 1,
#   motorcycle: 1,
#   camouflage: 1,
#   guy: 1,
#   bridge: 1,
#   man: 1,
#   Gate: 1,
#   Golden: 1,
#   front: 1,
#   motorcycle: 1,
#   toaster: 1,
#   refrigerator: 1,
#   cabinets: 1,
#   utensils: 1,
#   kitchen: 1,
#   microwave: 1,
#   oven: 1,
#   stove: 1,
#   car: 1,
#   seat: 1,
#   passenger: 1,
#   lap: 1,
#   dog: 1,
#   man: 1,
#   oven: 1,
#   kitchen: 1,
#   dishwasher: 1,
#   space: 1,
#   counter: 1,
#   plenty: 1,
#   seat: 1,
#   toilet: 1,
#   toilet: 1,
#   water: 1,
#   cat: 1,
#   drinking: 1,
#   toilet: 1,
#   bathroom: 1,
#   room: 1,
#   mirror: 1,
#   bathtub: 1,
#   sink: 1,
#   view: 1,
#   progress: 1,
#   game: 1,
#   basketball: 1,
#   monitors: 1,
#   computer: 1,
#   animal: 1,
#   car: 1,
#   foot: 1,
#   man: 1,
#   road: 1,
#   traffic: 1,
#   bowls: 1,
#   top: 1,
#   oranges: 1,
#   counter: 1,
#   kitchen: 1,
#   Whole: 1,
#   bikers: 1,
#   motorcycles: 1,
#   People: 1,
#   city: 1,
#   street: 1,
#   side: 1,
#   curb: 1,
#   top: 1,
#   mouse: 1,
#   man: 1,
#   lap: 1,
#   keyboard: 1,
#   monitor: 1,
#   workstation: 1,
#   hand: 1,
#   dog: 1,
#   bike: 1,
#   seat: 1,
#   woman: 1,
#   baby: 1,
#   leash: 1,
#   spots: 1,
#   countertop: 1,
#   stove: 1,
#   sink: 1,
#   view: 1,
#   Kitchen: 1,
#   flour: 1,
#   cards: 1,
#   van: 1,
#   credit: 1,
#   parking: 1,
#   meter: 1,
#   front: 1,
#   back: 1,
#   bike: 1,
#   woman: 1,
#   leash: 1,
#   Shepard: 1,
#   baby: 1,
#   German: 1,
#   view: 1,
#   view: 1,
#   room: 1,
#   mirror: 1,
#   terrain: 1,
#   window: 1,
#   toilette: 1,
#   can: 1,
#   trash: 1,
#   metal: 1,
#   stall: 1,
#   lid: 1,
#   side: 1,
#   MAN: 1,
#   BACKGROUND: 1,
#   BENCH: 1,
#   STATUE: 1,
#   PARK: 1,
#   FENCE: 1,
#   cobbler: 1,
#   coffee: 1,
#   plate: 1,
#   dessert: 1,
#   cup: 1,
#   side: 1,
#   Outdoor: 1,
#   Modern: 1,
#   Unique: 1,
#   sidewalk: 1,
#   restroom: 1,
#   Public: 1,
#   butter: 1,
#   chunk: 1,
#   vegetables: 1,
#   spoon: 1,
#   variety: 1,
#   Pot: 1,
#   Photo: 1,
#   plunger: 1,
#   towel: 1,
#   freshener: 1,
#   air: 1,
#   wall: 1,
#   appliances: 1,
#   steel: 1,
#   countertops: 1,
#   granite: 1,
#   sports: 1,
#   kitchen: 1,
#   person: 1,
#   motorcyclist: 1,
#   middle: 1,
#   helmet: 1,
#   street: 1,
#   canoe: 1,
#   roof: 1,
#   van: 1,
#   motorcycle: 1,
#   crane: 1,
#   corner: 1,
#   street: 1,
#   buildings: 1,
#   foreground: 1,
#   background: 1,
#   fence: 1,
#   blueberry: 1,
#   coffee: 1,
#   cup: 1,
#   bowl: 1,
#   strawberry: 1,
#   pastry: 1,
#   city: 1,
#   buildings: 1,
#   cars: 1,
#   lot: 1,
#   ground: 1,
#   street: 1,
#   game: 1,
#   baseball: 1,
#   feed: 1,
#   video: 1,
#   desk: 1,
#   tablet: 1,
#   someone: 1,
#   stove: 1,
#   shelves: 1,
#   kitchen: 1,
#   tops: 1,
#   food: 1,
#   counter: 1,
#   cat: 1,
#   bowl: 1,
#   toilet: 1,
#   seat: 1,
#   toilet: 1,
#   head: 1,
#   building: 1,
#   brick: 1,
#   cow: 1,
#   way: 1,
#   door: 1,
#   people: 1,
#   sun: 1,
#   houseplants: 1,
#   types: 1,
#   light: 1,
#   ledge: 1,
#   ...}}

# %%
values[2000:2010]
# Out:
# [15, 15, 15, 15, 15, 15, 15, 15, 15, 15]

# %%
with open('../../data/coco/coco_stats/spacy/3_noun/noun_stats.pkl', 'wb') as f:
    pickle.dump([noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns], f)

no_nouns_list, img_caps_list = zip(*(sorted(img_caps_per_noun_no.items(), key=lambda l: l[0] if type(l[0])==int else 99999)))
no_nouns_list, img_caps_list = list(no_nouns_list), list(img_caps_list)

del(no_nouns_list[0])
del(img_caps_list[0])
print(no_nouns_list)

with open('../../data/coco/coco_stats/spacy/3_noun/img_caps_per_noun_list.pkl', 'wb') as f:
    pickle.dump(img_caps_list, f)
# Out:
# [1, 2, 3, 'Rest']

# %%
# with open('../../data/coco/coco_stats/spacy/5_noun/noun_stats.pkl', 'wb') as f:
#     pickle.dump([noun_distr_per_noun_no, ex_count_per_noun_no, net_unique_nouns], f)
# 
# no_nouns_list, img_caps_list = zip(*(sorted(img_caps_per_noun_no.items(), key=lambda l: l[0] if type(l[0])==int else 99999)))
# no_nouns_list, img_caps_list = list(no_nouns_list), list(img_caps_list)
# 
# del(no_nouns_list[0])
# del(img_caps_list[0])
# print(no_nouns_list)
# 
# with open('../../data/coco/coco_stats/spacy/5_noun/img_caps_per_noun_list.pkl', 'wb') as f:
#     pickle.dump(img_caps_list, f)
# Out:
# [1, 2, 3, 4, 5, 'Rest']

# %% [markdown]
# ## Getting Verb Stats

# %%
max_verb_no = 3
# verb_distr_per_verb_no, ex_count_per_verb_no, net_unique_verbs = per_tp_no_distr_stats(max_verb_no, 'VB')

# Loading from saved location
with open('../../data/coco_stats/coco/verb_stats.pkl', 'rb') as f:
    verb_distr_per_verb_no, ex_count_per_verb_no, net_unique_verbs = pickle.load(f)

# %%
max_verb_no = 3
verb_distr_per_verb_no, ex_count_per_verb_no, net_unique_verbs = per_tp_no_distr_stats(max_verb_no, 'VB')

# %%
print('Total Examples with {} verbs per example: {}\n\n'.format(0, ex_count_per_verb_no[0]))

for i in range(1,max_verb_no+1):
    print('Total Examples with {} verbs per example: {}'.
          format(i, ex_count_per_verb_no[i]))
    print('Total Unique verbs with {} verbs per example: {}\n'.format(i, len(verb_distr_per_verb_no[i])))
    
print('Total Examples with > {} verbs per example: {}'.format(max_verb_no, ex_count_per_verb_no['Rest']))
print('Total Unique verbs with > {} verbs per example: {}\n'.format(i, len(verb_distr_per_verb_no['Rest'])))

print('Total number of unique verbs: {}'.format(len(net_unique_verbs)))

# %% [markdown]
# ## Plotting Verb Stats

# %%
values=[]
for i in range(0,max_verb_no+1):
    values.append(ex_count_per_verb_no[i])
values.append(ex_count_per_verb_no['Rest'])

x_ticklabel = list(np.arange(max_verb_no+1)) + ['Rest']

plot_bars(values, x_ticklabel, 'Number of verbs per example', 'Number of examples', 
          'Number of examples per verb number')

# %%
values=[]
for i in range(1,max_verb_no+1):
    values.append(len(verb_distr_per_verb_no[i])/len(net_unique_verbs))
values.append(len(verb_distr_per_verb_no['Rest'])/len(net_unique_verbs))

x_ticklabel = list(np.arange(1,max_verb_no+1)) + ['Rest']

plot_bars(values, x_ticklabel, 'Number of verbs per example', 'Unique verb distribution coverage', 
          'verb Distribution coverage per verb number')

# %%
# with open('../../data/coco_stats/coco/verb_stats.pkl', 'wb') as f:
#     pickle.dump([verb_distr_per_verb_no, ex_count_per_verb_no, net_unique_verbs], f)

# %% [markdown]
# ## Getting Noun-Verb statistics

# %%
import itertools

# Counts number of examples for each noun-verb
# for those sentences having number of noun types each of {0,1,2,..max_noun_no,'Rest'}

def per_nv_no_distr_stats(max_noun_no, max_verb_no):
    
    nv_distr_per_nv_no = {}
    ex_count_per_nv_no = {}
    
    for i in list(range(0,max_noun_no+1)) + ['Rest']:
        for j in list(range(0,max_verb_no+1)) + ['Rest']:
            nv_distr_per_nv_no[(i,j)] = {}
            ex_count_per_nv_no[(i,j)] = 0 
        
    net_unique_nvs = set()
    
    def put_words_in_dict(d, ws):
        for w in ws:
            if w not in d:
                d[w] = 1
            else:
                d[w] += 1
    
    for item in coco_train_anno_all['annotations']:
        tokens = tokenizer.tokenize(item['caption'])
        noun_types_per_ex = set()
        verb_types_per_ex = set()
        
        for word, pos in nltk.pos_tag(tokens):
            if 'NN' in pos:
                noun_types_per_ex.add(word)
            elif 'VB' in pos:
                verb_types_per_ex.add(word)               
                
        no_noun_types_per_ex = len(noun_types_per_ex)
        no_verb_types_per_ex = len(verb_types_per_ex)
        no_nv_types_per_ex = (no_noun_types_per_ex, no_verb_types_per_ex)
        if no_noun_types_per_ex > 0 and no_verb_types_per_ex > 0:
            nv_types_per_ex = list(itertools.product(noun_types_per_ex, verb_types_per_ex))
        
        if no_nv_types_per_ex == (0,0):
            ex_count_per_nv_no[(0,0)] += 1
            continue
            
        elif no_noun_types_per_ex == 0:
            idx2 = no_verb_types_per_ex if no_verb_types_per_ex <= max_verb_no else 'Rest'
            d_to_fill = nv_distr_per_nv_no[(0, idx2)]
            v_to_fill = verb_types_per_ex
            ex_count_per_nv_no[(0, idx2)] += 1       
            
        elif no_verb_types_per_ex == 0:
            idx1 = no_noun_types_per_ex if no_noun_types_per_ex <= max_noun_no else 'Rest'
            d_to_fill = nv_distr_per_nv_no[(idx1, 0)]
            v_to_fill = noun_types_per_ex
            ex_count_per_nv_no[(idx1, 0)] += 1                  
            
        elif no_noun_types_per_ex <= max_noun_no and no_verb_types_per_ex <= max_verb_no:
            d_to_fill = nv_distr_per_nv_no[(no_noun_types_per_ex, no_verb_types_per_ex)]
            v_to_fill = nv_types_per_ex
            net_unique_nvs.update(nv_types_per_ex)
            ex_count_per_nv_no[(no_noun_types_per_ex, no_verb_types_per_ex)] += 1
            
        elif no_noun_types_per_ex > max_noun_no and no_verb_types_per_ex > max_verb_no:
            d_to_fill = nv_distr_per_nv_no[('Rest', 'Rest')]
            v_to_fill = nv_types_per_ex
            net_unique_nvs.update(nv_types_per_ex)
            ex_count_per_nv_no[('Rest', 'Rest')] += 1
            
        elif no_noun_types_per_ex > max_noun_no:
            d_to_fill = nv_distr_per_nv_no[('Rest', no_verb_types_per_ex)]
            v_to_fill = nv_types_per_ex
            net_unique_nvs.update(nv_types_per_ex)
            ex_count_per_nv_no[('Rest', no_verb_types_per_ex)] += 1
            
        else:
            d_to_fill = nv_distr_per_nv_no[(no_noun_types_per_ex, 'Rest')]
            v_to_fill = nv_types_per_ex
            net_unique_nvs.update(nv_types_per_ex)
            ex_count_per_nv_no[(no_noun_types_per_ex, 'Rest')] += 1
        
        put_words_in_dict(d_to_fill, v_to_fill)
                
    return nv_distr_per_nv_no, ex_count_per_nv_no, net_unique_nvs

# %%
max_nv_no = 3
# nv_distr_per_nv_no, ex_count_per_nv_no, net_unique_nvs = per_nv_no_distr_stats(max_nv_nv, max_nv_nv)

# Loading from saved location
with open('../../data/coco_stats/coco/noun_verb_stats.pkl', 'rb') as f:
    nv_distr_per_nv_no, ex_count_per_nv_no, net_unique_nvs = pickle.load(f)

# %% [markdown]
# ## Plotting Noun-Verb Statistics

# %%
values = list(ex_count_per_nv_no.values())
x_ticklabel = list(ex_count_per_nv_no.keys())

x_ticklabel, values = zip(*(sorted(ex_count_per_nv_no.items(), key=lambda l: l[0][1] if type(l[0][1])==int else 99999)))
x_ticklabel, values = list(x_ticklabel), list(values)

plot_bars(values, x_ticklabel, 'Number of noun-verbs per example', 'Number of examples', 
          'Number of examples per noun-verbs statistics', rot_angle=45)

# %%
x_ticklabel = list(nv_distr_per_nv_no.keys())
x_ticklabel.remove((0,0))
values=[]
for el in x_ticklabel:
    if el == (0,0):
        continue
    elif el[0] == 0:
        values.append(0)
#         values.append(len(nv_distr_per_nv_no[el])/len(net_unique_verbs))
    elif el[1] == 0:
        values.append(0)
#         values.append(len(nv_distr_per_nv_no[el])/len(net_unique_nouns))
    else:
        values.append(len(nv_distr_per_nv_no[el])/len(net_unique_nvs))
        
x_ticklabel, values = zip(*(sorted(zip(x_ticklabel, values), key=lambda l: l[0][1] if type(l[0][1])==int else 99999)))
x_ticklabel, values = list(x_ticklabel), list(values)
            
plot_bars(values, x_ticklabel, 'Number of noun-verbs per example', '% Coverage', 
          'Noun-verb Distribution coverage per noun-verb number', rot_angle=45)

# %%
# with open('../../data/coco_stats/coco/noun_verb_stats.pkl', 'wb') as f:
#     pickle.dump([nv_distr_per_nv_no, ex_count_per_nv_no, net_unique_nvs], f)

# %% [markdown]
# ### Error investigation because of spacy versio mismatch

# %%
with open('../../data/coco/coco_stats/spacy/2_noun/img_caps_per_noun_list.pkl', 'rb') as f:
    icl2 = pickle.load(f)

with open('../../data/coco/coco_stats/spacy/3_noun/img_caps_per_noun_list.pkl', 'rb') as f:
    icl3 = pickle.load(f)

# %%
icl2[0] == icl3[0]
# Out:
# False

# %%
len(set(icl3[0])-set(icl2[0]))
# Out:
# 569

# %%
ann_file = '../datasets/coco/annotations/captions_train2017.json'
coco_caps=COCO(ann_file)
# Out:
# loading annotations into memory...
# Done (t=1.26s)
# creating index...
# index created!

# %%
img_caps_to_chk = set(icl3[0])-set(icl2[0])
_, cap_ids = zip(*img_caps_to_chk)
caps = coco_caps.loadAnns(list(cap_ids))

# %%
len(caps)
# Out:
# 569

# %%
caps[0]
# Out:
# {'image_id': 154179,
#  'id': 331958,
#  'caption': 'A very old looking plate is placed down. '}

# %%
spacy.prefer_gpu()
# nlp = spacy.load("en_core_web_sm")
nlp = spacy.load("en_core_web_trf")

# %%
wrong_samples=0
for idx in range(len(caps)):
    num_noun=0
    for tok in nlp(caps[idx]['caption']):
        if 'NN' in tok.tag_:
            num_noun+=1
    if num_noun > 1:
        print(caps[idx]['caption'])
        wrong_samples+=1
print(wrong_samples)
# Out:
# /dvmm-filer2/users/hammad/miniconda3/envs/gaila_v2/lib/python3.6/site-packages/torch/autocast_mode.py:141: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# a close up of many vases near one another
# Two men are standing near a propped up surfboard.
# a pizza sitting in an oven waiting to be cooked
# a close up of an older rusted car
# The rowing crew is rowing down the canal/
# A fire hydrant painted red white and green
# Three zebras walking together with there butts showing .
# A bunt cake has some glazed icing on it.
# unable to see image in this particular hit
# there giraffes in a penned area standing outside
# One zebra is front of the other zebra.
# A close up of a black and white design.
# This is a dirty urinal in a bathroom.
# A brown cake that has half of it missing.
# A very old looking oven sitting near the road.
# a close up of an old wooden stop sign
# a close up of a small elephant behind a large elephant
# Brown cows in a green field standing and staring.
# Two animals are standing in an arid plain.
# a close up of many elephants near one another
# a close up of a urinal and a device next to it
# A white horse sitting inside of a stable.
# A little boy is getting ready to do some skateboarding.
# a yellow and green parrot sitting on a branch
# A red stop signed has been altered to say stop hate.
# Two cats are snuggled and sleeping on a bedspread.
# A close up of some very tasty looking food.
# The coconut doughnut that they are holding has been bitten.
# The horses are all grouped together in the stable.
# There s a van with grafting on thevoutsidevif the van
# A red vase has green stems coming out of it.
# A young girl is standing on a tipped up skateboard.
# A kitten peaking out of a high top sneaker.
# A close up of a blue and a pink sprinkled doughnut.
# A surfboard rests in the back seat of a convertible.
# Two cows standing next to each other next to tub.
# a small green plant that has leafs on it
# A red train and a blue/yellow train, stopped, next to each other.
# there are two zebras that are running in the wild
# There are two giraffes standing together in the wild
# there are many zebras that can be seen here in the wild
# An old moped parked near a red building.
# there are three giraffes embracing in the wild
# An orange and white kitten laying on a chair.
# Lap top computers can be used just about anywhere.
# A man is eating a powdered donoguht
# a close up of two zebras standing close to one another
# We are looking at a close up shot of a tulip petal.
# two guys one in blue holding a remote and laughing
# The bagel appetizers are waiting to be heated.
# Delicate naked stems emerge from five brown vases.
# An old plane  is flying over several short silos.
# Two zebra traveling across a sparsely grassed plain.
# Two geese in water looking at each other.
# a close up of a person kissing another person
# A sideways stoplight hangs next to some wires.
# a close up of a clean white toilet
# A van that has graffiti   written on it.
# there are two animals staining by each other in the wild
# A large residential kitchen heavily decorated in white.
# a close up of two stuffed animals near one another
# a giraffe that is looking down outside in the wild
# a red rose that is coming out of a vase
# A close up of some freshly grown broccoli
# a small kitchen clustered with small  utensils
# unable to see image in this particular hit
# Nicely decorated room with extremely large white bedspread.
# a close up of a young child smiling
# This is a close up of a black bears face
# a wooden device built to hold and store multiple utensils
# The two people are at the top getting ready to ski down.
# A donut with white and brown swirled frosting.
# a hot dog with some crazy topping on it
# A man that is standing next to train.
# Photograph of an outdoors zone that looks unbelievable.
#
# A close up of a not so happy white kitty.
# A dinning room and a living room combined .
# A woolly cow relaxing in an enclosed pasture.
# A giraffe is moving across an arid plain.
# There are three giraffes together in the wild
# a t.v. that is sitting on a wooden t.v. stand
# A close up of a lanyard key chain.
# The surfer expertly crouches to finish the ride.
# There is a freshly made pizza out of the oven
# A very small and cute kitten in a cup.
# a close up of some white puffy balls
# a close up of two pots in an oven
# Small jelly donuts on a plate, jelly dripping out.
# an outdoors oven made to look like a head
# An old oven has ceramic trim on it
# Boy on skateboard that is airborne next to a ramp.
# a close up of a cat laying down
# there is a brown colored zebra seen here in the wild
# A very tall giraffe stands in the wild alone
# On zebra standing and staring while another zebra is eating.
# there are three zebras standing together in the wild
# a big t.v. that  has a cat sitting next to it
# The young girl is learning to ride her skateboard outside.
# A golden bicycle is parked next to sidewalk.
# A green eyed cat is on a blue bedspread.
# some scissors brand new still all boxed up
# We are looking at a small living room/
# He got all his items laid out to take to work.
# a close up of a hat wearing a small hat
# A black cat sleeping on a white bedspread.
# there are three elephants walking together in the wild
# The toothbrush is next to paste and floss.
# a brown black and white kitten drinking from a bottle
# there is fresh food being made in the oven
# A kitten licking itself while surfing the computer.
# There is a red rose on the white bed
# The grinning child is near another running child.
# A brown and white cat is on a bedspread.
# A big zebra and a little zebra standing and looking.
# A close up of a sheep standing next to another sheep.
# a small toy is standing on a toy skateboard
# A close up of a microwave that is currently on.
# Young surfer quite vertical on an incoming wave
# there is a very bright blue parrot sitting on a hand
# a close up of two polar bears near one another
# a close up of two people sitting near one another
# A black dog sitting on a skateboard looking bored.
# a t.v. that is sitting on top of a t.v. stand
# a close up of a sliced orange
# An upside down skateboard surrounded by black bags
# Vandalized stop side outside in clear blue skies.
# A clock is built into this wooden bookshelf.
# Colorful bluebird sitting on branch looking to the left
# a close up of a small elephant near a large elephant
# there are many different animals that can be seen in the wild
# A boy practices skateboarding while another boy watches.
# A swirled pizza fresh from the commercial oven behind it
# A blue train is overtaking the white train
# a close up of two giraffes near one another
# there are two elephants that are embracing in the wild
# Well made be in clean and neat bedroom setting.
# a cat that is next to a t.v.
# A moped parked near an oddly shaped door.
# Male surfer getting ready to ride a wave.
# The sides of this drive through are painted yellow.
# There is a taxing rolling through a wet street
# A large clock with an astrological attached to it.
# The motorcyclists are enjoying a quick   kiss together.
# a zebra is standing in a corral outside
# An inflatable is behind ng carried during a parade.
# Some colorful kites hanging outside an old building.
# A close up of a banana that is beginning to ripen
# The jumping skateboarder is Photoshopped black and white.
# a man is holding a large soft pretzel
# A close up of a cats profile is shown.
# A surfer standing upright on a small wave
# Small baby playing with a black and orange kitten.
# Photograph of a public toilet as taken from above
# A grey and green airplane with a blue and red decal.
# Students are lying on the grassy square studying.
# a tan white and blue truck and another blue truck
# a close up of some fresh green broccoli
# A gross bathroom has graffiti all over it.
# An egret tiptoes through the warm, shallow water.
# a man jumping up but having his skateboard fall down
# A slightly knocked over stop sign next to a small empty road.
# Good is placed on a white plate and looks yummy.
# Two old fashioned plows each with two horses hooked up to it
# A close up of a very cute black cat.
# sombody that is skiing down a snowy hill
# A zebra grazes while another zebra looks on.
# A close up of a urinal in a restroom.
# a close up of three older men standing near one another
# A sickly looking white hose inside of a stable.
# GIRAFFE WITH A VERY LONG NECK STANDING ALONE
# A close up of some very pretty zebras close together.
# Small kitten warming up to a shy dog.
# a delicious donut with white icing on it
# A kitten sitting in a high top sneaker.
# A toilet that is sitting next to a urinal.
# a small t.v. that is next to a bed
# A close up of several different breaded pastries.
# a red and  black bus being towed in by a flatbed
# there are three zebras standing together in the wild
# Man hug as they are dressed in colorful costumes.
# A zucchini pizza is being prepared to be cut.
# an old rusted fire hydrant sitting on broken up concrete
# a big elephant that is outside in the wild
# a close up of two bears near one another
# there is a horse that can be seen running in the wild
# Young man with skateboard appearing like he just fell down.
# A kitten looking out sideways from a chair.
# a close up of an elephant with another elephant
# there are many zebras that can be seen in the wild
# A bunkbed sitting in an un-cluttered room.
# A  black and white duck scratching itself with it's beak.
# Colorful kites hanging under and awning in an outdoor shop.
# THERE ARE HORESE WALKING TOGETHER ON THE BEACH
# There are two laptop computers beside each other
# A close up of several zebras grouped together.
# a close up of two black sheep
# A close up of a ceramic bowl that has been painted.
# A couple of geese are out to pasture .
# The Cal is walking out of the stable.
# a close up of two cats near one another
# a close up of two zebras near one another
# a close up of a yellow and blue striped tie
# A ship is coming in to port and is about to be docked.
# A female skateboarding leaning in to a turn.
# Some very cute looking geese in a pen.
# A close up of a dark haired cat looking off
# two cats curled up, sleeping on a beige bedspread.
# A paraskier is paragliding through a snowy landscape.
# An empty home with a rather large bookshelf.
# a close up of three hot dogs near one another
# a close up of two people sitting close to one another
# A toilet that has a crowbar set next to it.
# there are many zebras that can be seen together in the wild
# An elephant is walking in the wild alone.
# We are looking at the side of a buildingl
# The two zebras are grazing in the wild
# a close up of a parked motorcycle
# A red and beige train pulling up to the train -platform
# A very unpleasant looking bathroom with a urinal and commode
# a cat that is watching a t.v. show
# The red firetruck has No2 written on it.
# Many different utensils hanging up on a wall.
# A close up of two small puppies playing with each other.
# A close up of a small, dingy public toilet.
# A close up of what vegetables look like after being seasoned.
# A close up of a very nice looking bike parked.
# a close up of a smaller door in a regular sized door
# Several colorful kites hanging outside an open shop
# We are looking down at a urinal in the floor.
# An impressive looking blue and gold plain waiting on a runway
# The surfboard rider seems to be wiping out.
# A close up of an old fashioned motorcycle.
# unable to see this image in this particular hit
# A man's skateboard flips around as he jumps up.
# there is a pizza that has been taken out of the oven
# A tired dogi s sleeping on the couch
# Colorful kites being flown around a tall building.
# a close up of two beds near one another
# Two white geese standing outside in the grass
# A pizza oven with a baking pizza inside it.
# a close up of a large and a small zebra
# A uncooked pizza is being put into the pizza oven
# a close up of a small zebra and a larger zebra
# A broken down building with a clock that collapsed.
# There giraffes all around a large green tree.
# A very tall and old  Building on a cloudy day.
# there is a white rose inside of a small white and blue vase
# Three guys have skateboards two are riding them one is holding his.
# A cowed laying down in a fenced in enclosure
# This is a close up of a keyboard.
# A field with four geese walking around in a field.
# A kitten sitting beside a remote control glances upward.
# a close up of a dog smelling a hot dog
# A close up of a plane passing overhead.
# Several large covered pans are seen in a hot old fashioned oven.
# The person is standing next to the upside down skateboard.
# A multi colored parrot sitting on a rope.
# A close up of a man looking surprised.
# An orange sign says Guzzled next to an Do Not Enter sign.
# A motorcycle covered in what looks like a putting green.
# A white dog is on a white bedspread.
# Two homemade pizza ready to go in the oven
# there are many elephants walking together in the wild
# The bus is by the bus stop now.
# A dead looking rose is in a mosaic vase.
# Intense-looking, young skateboarder holding a decorated skateboard sideways.
# two very big elephants walking in the wild
# Prone surfer paddling while waiting for a wave to break.
# Two white geese walking beside a small pond.
# A orange and yellow bedspread is against a blue wall.
# A thick crusted pizza just taken out of the oven
# a close up of two remotes sitting next to each other
# A girl by herself in an asian looking setting.
# The two geese are flying by some trees.
# There is a large chicken being cooked in the oven
# A bed has a golden bedspread and pillow.
# a close up of a foldable bike
# a close up of two laptops near one another
# A huge roman numeral close outside of a house.
# there are many elephants that can be seen in the wild
# A light blue surfboard standing upright on the beach.
# A brown and gold antique vase being displayed.
# some garlic hang next to some bananas
# Several items outlined in white with some orange and red items.
# Two men who are about to give each other a hi-five.
# A shirtless man riding on a white moped.
# a close up of a frie hydrant with a blurry background
# This is a red rose bud in a clear vase.
# A boat that is coming in to shore to be docked
# a close up of a stone oven
# a public bus parked by a blue bus stop
# there is a large bus that is stopped at a blue bus stop
# Two men are conversing over an inflatable outside
# A goose who is flying over some other geese.
# a close up of three vases near one another
# A pink bedspread is featured in this bedroom.
# Two giraffes standing alone in a large, open plain.
# a close up of a large and a small cow
# there are many giraffes that can be seen here in the wild
# a close up of two zebras near one another
# Skate boarder getting totally horizontal during a stunt
# a blue and white bus leaving the bus stop
# a close up of a neatly made bed
# A sign that says stop that has writing on it.
# a close up of two similar ties hanging
# Two brown horses are standing outside the stable.
# There is a wake boarder preparing to start riding
# A close up of a hairy white cat outside.
# A close up of a kitten touching a bottle.
# Small orange kitten sitting in a wooden bowl.
# a close up of food cooking in an oven
# This is an older main preparing to throw a disc.
# A cake mostly eaten made with blue icing
# Two stoplights one focused one blurry showing green.
# Counter top with an oven built-in to it.
# Bananas out from of store that appear freshly picked and ripening.
# garlic hanging up with a sign next to them
# A zebra standing next to a zebra sitting.
# A woman holding a croissant while eating it.
# A cake is cracked as it comes fresh out of the oven
# A young grey sheep sits next to an older wholly sheep.
# a close up of a young person and an older person
# A dingy bathroom has been photographed in white.
# A close up of some very tasty looking pizza.
# THERE ARE PEOPLE STANDING AROUND WITH BIKES ALL OVER
# A wooden bed has a white bedspread and pillow.
# A bathroom urinal is close up in white.
# a close up of a small white public toilet
# Surf boards lined up one next to the other
# Several boats docked and some have covers on them
# A new looking bathroom is all in white.
# a fridge with writing on it left outside
# A small pizza has a curly topping on it.
# Three geese that are standing by a pond.
# unable to see image in this particular hit
# there are many animals that can be seen in the wild
# A man leisurely runs to base as he laughs.
# A bathroom is mostly decorated in white.
# A train that is sitting next to station.
# a close up of a knitted stuffed animal
# The bouquet has one red rose in it.
# This is a kitten sitting on a laptop.
# A close up of a very tasty looking pizza.
# cook prepares dish by putting it into the oven
# a close up of a black and white cow
# a close up of a neatly made bedroom
# THERE IS A SHEEP IN THE BARN
# A close up of two small dogs running.
# A very pretty beach with a very big pretty sail flying above,
# A black and white dog laying on a floral bedspread.
# Black cat sleeping on a comfortable looking bedspread.
# A dog is sitting on a yellow, blue, and white bedspread.
# There are many Giraffes that are gathered here in the wild
# a close up of a slightly burned pizza
# A young man is jumping with his skateboard outdoors.
# Two people, in red and green, are going skiing.
# a large t.v. hanging off a purple wall
# A giraffe stands next to another giraffe next to foliage.
# A large elephant standing in the wild
# a close up of two horses standing near one another
# a close up of two giraffes near one another
# This is a memorial bench with a can sitting on it.
# a close up of a yellow fire hydrant
# A large pizza just removed from the oven
# a close up of two giraffes standing near one another
# a close up of legos and cake
# A close up of a black and white cow is shown.
# A black short vase with a red rose
# There are many horses running together in the wild
# A close up of a female getting her hair cut
# a close up of two cats near one another
# A small white kitten playing with a string
# Several antique looking suitcases stacked on each other.
# There are many zebras together in the wild
# Several zebras walking together in the wild
# THERE ARE PEOPLE STANDING IN THE KITCHEN TALKING
# two city buses one  following the other
# A close up of some food, colored off white and green.
# A close up of some very tasty looking food.
# A large pizza prepared and ready to go in the oven
# Three skiers prepare for a simple downhill run.
# a cat that is sitting next to a t.v.
# a close up of dark and white chocolate
# An expensive and clean oven in a kitchen
# there are two very tall giraffes that are in the wild
# A single, long stemmed rose is sticking up out of a toilet.
# Male surfer riding across a wide wave, about ready to fall.
# Someone is holding their skateboard upright next to themselves.
# unable to see this image in this particular hit
# there are two giraffes embracing each other in the wild
# A pink colored bedroom with very colorful bedding.
# there is a very tall zebra standing alone in the wild
# a close up of a parked motorcycle
# a close up of a cows near other cows
# A kitten resting comfortably and cozy on a blanket.
# a close up of two bears close to one another
# Two beautiful zebra's, one brushing up against the other.
# a close up of a disassembled remote control
# a black and white god with blue frisbey
# A close up of a keyboard is shown.
# A close up of a very small and cute bird.
# A close up of a very unique looking building.
# a little boy that is standing on skii
# Large, open, empty chest in an abandoned, rundown buliding
# A cat standing close to and looking at two geese.
# two white vases one empty and one filled with flowers
# White bauble vase with a red rose in it.
# An orange cat sits on an empty bookshelf.
# A close up view of a white male urinal
# a close up of a red white and blue fire hydrant
# a close up of many different sized blenders
# there are two sandwiches being cooked in the oven
# Two elephants face each other in the wild
# there are many zebras that are walking together in the wild
# cooking utensils hanging on a lazy susan
# A fire hydrant painted red white and green.
# THERE IS A HORSE THAT IS STANDING LOOKING AT THE BARN
# a close up of two motorcycles parked near each other
# A green and red parrot eating a banana.
# Three streetlights are hanging and showing green.
# mmmmmm mm m nn n n n n n n n n n n n
# A close up of a round pastry topped with icing.
# Two shiny blue birds are beak to beak.
# The bed is neatly made with the bedspread turned down.
# Tagged ewe with young in grassy open field.
# A small white bedroom with an ornate white afghan.
# A girl sitting down next to an upside down skateboard.
# An upside down stop sign that has been defaced.
# A bulldog sits on a blue and white bedspread.
# a cup that has a pink rose in it
# a brown and black are sitting on the floor.
# a t.v. stand that has a t.v. and some other electrical equipment
# A moped that is sitting underneath a window.
# a close up of a truck with another truck behind it
# a close up of two elephants near one another
# Several stop signs that have been grouped together.
# A close up of an empty black suitcase.
# A yellow  is sitting on a branch
# a close up of a cake being cooked in an oven
# A yellow and black sign that reads "floodway."
# A bus sits idle at a public bus stop
# A food entree is shown next to sauce.
# a small and dirty zebra inside of a corral
# A woman in purple and green is skiing.
# A street has an upside down stop sign on it.
# a close up of a person reaching in an oven
# a close up of a large and a small elephant
# A close up of a remote control beside another remote control.
# A close up of two brown horses and one black one.
# a close up of two people walking close together
# Vase with some pink flowers inside of it
# A baseball mitt with a baseball sitting inside of it.
# A very nice and clean and sparsely decorated counter top.
# 453

# %%
for tok in nlp('a close up of a large and a small elephant'):
    if 'NN' in tok.tag_:
        print(str(tok), tok.tag_)
# Out:
# close NN
# elephant NN

# %%
torch.cuda.device_count()
# Out:
# 0
